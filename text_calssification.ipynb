# %% [markdown]
# # Prerequisites

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score , accuracy_score

import nltk
from nltk.stem.porter import PorterStemmer

import gensim

from keras.models import Sequential
from keras.layers import Embedding,LSTM,Dense,SpatialDropout1D , Dropout,Conv1D
from keras.optimizers import Adam

# %% [markdown]
# # Reading data

# %% [markdown]
# reading data and showing

# %%
all_data = pd.read_csv("data.csv",na_values = "[]" , keep_default_na=True)

# %%
print(all_data.head())
# Out:
#       product_id                                            title      vendor  \
# 0  3937721221199  Fidele Super Premium Adult Large Breed Dog Food      Fidele
# 1  7353058033889                  Foldable Pet Toys Linen Storage   Cap Point
# 2  6594773549129                                   Bok Dok Diaper   Pets Home
# 3  4802008318014                            Tastybone Toy Chicken   TastyBone
# 4  1779705151539              Leather Leash Tab - Short Dog Leash  Mighty Paw
#
#                                                 tags                category
# 0  ['Adult', 'Bangalore', 'Chennai', 'Chicken', '...  Animals & Pet Supplies
# 1                                                NaN  Animals & Pet Supplies
# 2  ['Brand_Pet Arabia', 'Category_Pets Home', 'Ca...  Animals & Pet Supplies
# 3                                                NaN  Animals & Pet Supplies
# 4                 ['Leash', 'Leash Tab', 'Training']  Animals & Pet Supplies

# %%
all_categories = pd.unique(all_data["category"])

print(all_categories)
# Out:
# ['Animals & Pet Supplies' 'Apparel & Accessories' 'Arts & Entertainment'
#  'Baby & Toddler' 'Business & Industrial' 'Cameras & Optics' 'Electronics'
#  'Food, Beverages & Tobacco' 'Furniture' 'Hardware' 'Health & Beauty'
#  'Home & Garden' 'Luggage & Bags' 'Media' 'Office Supplies'
#  'Religious & Ceremonial' 'Software' 'Sporting Goods' 'Toys & Games'
#  'Vehicles & Parts']

# %%
len(all_categories)
# Out:
# 20

# %% [markdown]
# # Analyzing Data

# %% [markdown]
# checking number of samples in each cateory

# %%
all_categories_information = {}

for category in all_categories:
    num_samples = len(all_data[all_data["category"] == category])
    print("Number of samples from category of ",category," : ", num_samples)
    all_categories_information[category] = num_samples
# Out:
# Number of samples from category of  Animals & Pet Supplies  :  500
# Number of samples from category of  Apparel & Accessories  :  1000
# Number of samples from category of  Arts & Entertainment  :  200
# Number of samples from category of  Baby & Toddler  :  200
# Number of samples from category of  Business & Industrial  :  100
# Number of samples from category of  Cameras & Optics  :  50
# Number of samples from category of  Electronics  :  100
# Number of samples from category of  Food, Beverages & Tobacco  :  400
# Number of samples from category of  Furniture  :  200
# Number of samples from category of  Hardware  :  50
# Number of samples from category of  Health & Beauty  :  400
# Number of samples from category of  Home & Garden  :  400
# Number of samples from category of  Luggage & Bags  :  400
# Number of samples from category of  Media  :  300
# Number of samples from category of  Office Supplies  :  100
# Number of samples from category of  Religious & Ceremonial  :  20
# Number of samples from category of  Software  :  50
# Number of samples from category of  Sporting Goods  :  400
# Number of samples from category of  Toys & Games  :  300
# Number of samples from category of  Vehicles & Parts  :  100

# %% [markdown]
# ## Plotting data

# %%
plt.rcParams["figure.figsize"] = (40,15)
plt.bar(list(all_categories_information.keys()), list(all_categories_information.values()))
plt.xlabel('Category')
plt.ylabel('Number of samples')
# Out:
# Text(0, 0.5, 'Number of samples')

# %% [markdown]
# **We see that the dataset is unbalanced**

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# Delete product_id colum because it is excess and not needed.

# %%
all_data.pop("product_id")
# Out:
# 0       3937721221199
# 1       7353058033889
# 2       6594773549129
# 3       4802008318014
# 4       1779705151539
#             ...
# 5265    4637089464407
# 5266    4996632444987
# 5267    5528541003927
# 5268    1395163889730
# 5269    3535679324240
# Name: product_id, Length: 5270, dtype: int64

# %% [markdown]
# ### define mapping class names to labels

# %%
categories_to_label = {}
labels_to_categories = {}

for idx, category in enumerate(all_categories):
    categories_to_label[category] = idx
    labels_to_categories[idx] = category

print(categories_to_label)
print(labels_to_categories)
# Out:
# {'Animals & Pet Supplies': 0, 'Apparel & Accessories': 1, 'Arts & Entertainment': 2, 'Baby & Toddler': 3, 'Business & Industrial': 4, 'Cameras & Optics': 5, 'Electronics': 6, 'Food, Beverages & Tobacco': 7, 'Furniture': 8, 'Hardware': 9, 'Health & Beauty': 10, 'Home & Garden': 11, 'Luggage & Bags': 12, 'Media': 13, 'Office Supplies': 14, 'Religious & Ceremonial': 15, 'Software': 16, 'Sporting Goods': 17, 'Toys & Games': 18, 'Vehicles & Parts': 19}
# {0: 'Animals & Pet Supplies', 1: 'Apparel & Accessories', 2: 'Arts & Entertainment', 3: 'Baby & Toddler', 4: 'Business & Industrial', 5: 'Cameras & Optics', 6: 'Electronics', 7: 'Food, Beverages & Tobacco', 8: 'Furniture', 9: 'Hardware', 10: 'Health & Beauty', 11: 'Home & Garden', 12: 'Luggage & Bags', 13: 'Media', 14: 'Office Supplies', 15: 'Religious & Ceremonial', 16: 'Software', 17: 'Sporting Goods', 18: 'Toys & Games', 19: 'Vehicles & Parts'}

# %% [markdown]
# This is for showing how much explicit null exists in dataframe

# %%
all_data.isnull().sum()
# Out:
# title         0
# vendor        3
# tags        460
# category      0
# dtype: int64

# %% [markdown]
# As it shows we have missing values in two columns : "vendor" , "tags"
#
# We should fill these with some corresponding appropriate texts.
#
# so for handling missing information and preprocessing we have some ideas:
#
# 1.
#
#  Removing all rows with missing values: this is not good idae in this case, because the number of missed values are realtively great and by this we miss very information.
#
#
# 2.
#
#  Labeling "tags" missed values with "UNKNOWN" (an extra label for showing misinfomation).
#  this solution adds bias to Model and other better solutions exist.
#
#
# 3.
#
# **The better solution is to fill missing information based on other colums.**

# %% [markdown]
# ### handle missing information in "vendor"

# %% [markdown]
# For handling missing information in this column I had an idea:
# - Select data with same category with misvalued data category
# - The nearest neighbour of the misvalued data is the upper or downer row, so we choose it
# - choose the neighbour "vendor" as misvalued "vendor" in this column
#
# This is because the vendors in same categories probably have same products.

# %%
index_list_of_missing_information = all_data[all_data["vendor"].isnull()].index.to_list()

for idx in index_list_of_missing_information:
    if all_data.loc[idx,"category"] == all_data.loc[idx-1,"category"]:
        
        all_data.loc[idx,"vendor"] = all_data.loc[idx-1,"vendor"]
        
    elif all_data.loc[idx,"category"] == all_data.loc[idx+1,"category"]:
       
        all_data.loc[idx,"vendor"] = all_data.loc[idx+1,"vendor"]
    
    print(all_data.loc[idx,:])
# Out:
# title       WYSIWYG Rainbow Bubble Tip Anemone * RBTA * Li...
# vendor                                       Always Whiskered
# tags        ['AFCO-', 'AFCO-EB', 'AFCO-EB124448705859', 'A...
# category                               Animals & Pet Supplies
# Name: 457, dtype: object
# title                  Cinnamon Honey Stix
# vendor                   Bellwoods Brewery
# tags        ['Honey', 'Retail', 'Spently']
# category         Food, Beverages & Tobacco
# Name: 2499, dtype: object
# title       SCHWINN BICYCLE HUB ROAD BIKE FRONT QUICK RELEASE
# vendor                                               Lib Tech
# tags                                                      NaN
# category                                       Sporting Goods
# Name: 4673, dtype: object

# %% [markdown]
# ### handle missing information in "tags"

# %% [markdown]
# For handling missing information in this column I had an idea:
# - Select the "title" in this row which has misvalued "tags".
# - Tokenize and split "title" words and label each word as a "tag" in "tags" column.
#
#
# This is because It can be seen that the words in tags column are very similar to title words.

# %%
index_list_of_missing_information = all_data[all_data["tags"].isnull()].index.to_list()

for idx in index_list_of_missing_information:
    tag_string = "["
    for title_word in all_data.loc[idx,"title"].split(" "):
        tag_string = tag_string + "'" +  title_word + "',"

    tag_string = tag_string[0:-1]
    tag_string +="]"
    all_data.loc[idx,"tags"] = tag_string

# %%
all_data.isnull().sum()
# Out:
# title       0
# vendor      0
# tags        0
# category    0
# dtype: int64

# %% [markdown]
# ### some cleaning data on texts

# %% [markdown]
# In this section we want to do some cleanings.
#
# The final task is a text classification task, so:
#
# 1. removing sentences with some extra postfixes and prefixes such as .com, .org ,... in data. this can be improve model accuracy, because these are meaningless words in final task and can add bias to final model.
#
# 2. removing mainingless chars such as &,^,%,... and filter any non-English char
#
#
# 3. Normalizing data : lowercasing all chars for removing bias and difference between uppercases and lowercases chars.
#
# 4.  Removing Numbers from data: because is not important.
#
# 5. Stemming :  for getting the root of each word : it means that jumps , jumping, jumped  all of them are converted to "jump" which is root of them. and it helps model gets better because of removing difference between all shapes.

# %%
forbidden_ext = [".com", ".org" , ".co", ".(ltd)", "inc.",  "int.", ".shop", ".ie" ,".au",
                 "ltd.", ".ph" , ".in" , ".us", ".ae" , ".kw" , ".pl"]

forbidden_pre = "www."

stemmer = PorterStemmer()

for index, row in all_data.iterrows():
    
     ###### title ######
    text = row["title"].lower()
    print(text)
    
    
    result_text = ""
    for char in text :
        if char!=" ":
            if (char.isalnum()) and (not char.isnumeric()):
                result_text = result_text + char
        else:
            result_text = result_text + char
            
    
    ### stemming
    words = result_text.split(" ")
    root_words = []

    for word in words:
        root_words.append(stemmer.stem(word))
        
    result_text = " ".join(root_words)
    
    print(result_text) 
    all_data.iloc[index,0] = result_text


    
    
    ###### vendor ######
    
    text = row["vendor"].lower()
    print(text)
    
    for ext in forbidden_ext:
        if ext in text:
            
            text = text.replace(ext,"")
            
        if forbidden_pre in text:
            
            text = text.replace(forbidden_pre,"")
          
    
    result_text = ""
    for char in text :
        if char!=" ":
            if (char.isalnum()) and (not char.isnumeric()):
                result_text = result_text + char
        else:
            result_text = result_text + char
    
    print(result_text) 
            
    ### stemming
    words = result_text.split(" ")
    root_words = []

    for word in words:
        root_words.append(stemmer.stem(word))
        
    result_text = " ".join(root_words)
    
    print(result_text) 

    
    all_data.iloc[index,1] = result_text
    
    
    
    
   
    ###### tags ######
    text = ""
    print(row["tags"])
    for char in row["tags"]:
        if char == "[" or char == "'"  or char == "]" :
            continue
        
        elif char == "," or char == " " or char == "_" : 
            text = text + " "
        else:
            text = text + char
            
        
    text = " ".join(text.split())
    text = text.lower()
    
    result_text = ""
    for char in text :
        if char!=" ":
            if (char.isalnum()) and (not char.isnumeric()):
                result_text = result_text + char
        else:
            result_text = result_text + char
            
    
    ### stemming
    words = result_text.split(" ")
    root_words = []

    for word in words:
        root_words.append(stemmer.stem(word))
        
    result_text = " ".join(root_words)
    
    print(result_text) 
    all_data.iloc[index,2] = result_text 
    
    
    ### Category ####
    
    row['category'] = categories_to_label[row['category']]
    all_data.iloc[index,3] = row['category']
# Out:
# fidele super premium adult large breed dog food
# fidel super premium adult larg breed dog food
# fidele
# fidele
# fidel
# ['Adult', 'Bangalore', 'Chennai', 'Chicken', 'Doberman', 'Dog Dry Foods', 'Fidele', 'German Shepherd', 'Golden Retriever', 'Great Dane', 'HighPriority', 'Imported', 'Labrador', 'Less than 1000', 'Less than 2000', 'Less than 500', 'Mastiff', 'Orange Pet Nutrition']
# adult bangalor chennai chicken doberman dog dri food fidel german shepherd golden retriev great dane highprior import labrador less than  less than  less than  mastiff orang pet nutrit
# foldable pet toys linen storage
# foldabl pet toy linen storag
# cap point
# cap point
# cap point
# ['Foldable','Pet','Toys','Linen','Storage']
# foldabl pet toy linen storag
# bok dok diaper
# bok dok diaper
# pets home
# pets home
# pet home
# ['Brand_Pet Arabia', 'Category_Pets Home', 'Category_Small Pets Supplies', 'Type_Pet Home', 'Type_Pet Supplies']
# brand pet arabia categori pet home categori small pet suppli type pet home type pet suppli
# tastybone toy chicken
# tastybon toy chicken
# tastybone
# tastybone
# tastybon
# ['Tastybone','Toy','Chicken']
# tastybon toy chicken
# leather leash tab - short dog leash
# leather leash tab  short dog leash
# mighty paw
# mighty paw
# mighti paw
# ['Leash', 'Leash Tab', 'Training']
# leash leash tab train
# pridebites texas guitar dog toy
# pridebit texa guitar dog toy
# pride bites
# pride bites
# pride bite
# ['Brand_PrideBites', 'Toy Type_Plush']
# brand pridebit toy type plush
# burns sensitive pork & potato
# burn sensit pork  potato
# burns
# burns
# burn
# ['10-25', '25-50', '50-75', 'Adult', 'burns', 'Coat', 'dog-food', 'Food Delivery', 'JANSALE18', 'Natural', 'nonsale19', 'Sensitive', 'size-12kg', 'size-2kg', 'size-6kg', 'Skin']
#    adult burn coat dogfood food deliveri jansal natur nonsal sensit sizekg sizekg sizekg skin
# bully sticks & dog toy
# bulli stick  dog toy
# adog.co
# adog
# adog
# ['Bully Sticks', 'Dog Chew Toys', 'Dog Toys']
# bulli stick dog chew toy dog toy
# kazoo tough giraffe dog toy
# kazoo tough giraff dog toy
# kazoo
# kazoo
# kazoo
# ['Brand_Kazoo', 'JUNE2021', 'kazoo', 'Material_Plush', 'Plush']
# brand kazoo june kazoo materi plush plush
# orgo - dog biscuits fresh milk
# orgo  dog biscuit fresh milk
# petku
# petku
# petku
# ['Brand_Orgo', 'Category_Dogs', 'dogs', 'Lifestage_All lifestages', 'orgo', 'Price_Rp 0 to Rp 100.000', 'Subcategory_Treats', 'treats']
# brand orgo categori dog dog lifestag all lifestag orgo price rp  to rp  subcategori treat treat
# alien flex wormhole | dog toy
# alien flex wormhol  dog toy
# zee.dog
# zeedog
# zeedog
# ['active', 'bf_4_toys_20', 'cm_30', 'cm_sale', 'collection:alien_flex', 'color_pink', 'new-product-page', 'ThrowAndFetch', 'Toys', 'Tugging', 'type:throw_toy']
# activ bf  toy  cm  cm sale collectionalien flex color pink newproductpag throwandfetch toy tug typethrow toy
# wave scissor aquatic plant cleaning tool
# wave scissor aquat plant clean tool
# pet clever
# pet clever
# pet clever
# ['Aquarium Cleaning Supplies', 'Aquariums & Kits', 'Fish', 'Other Pets', 'rr_track_Fish']
# aquarium clean suppli aquarium  kit fish other pet rr track fish
# mpets - chicken and cheese snack
# mpet  chicken and chees snack
# petku
# petku
# petku
# ['Brand_MPETS', 'Category_Cats', 'cats', 'Lifestage_All lifestages', 'MPETS', 'Price_Rp 100.000 to Rp 500.000', 'Subcategory_Treats', 'treats']
# brand mpet categori cat cat lifestag all lifestag mpet price rp  to rp  subcategori treat treat
# aquatopia betta care pack
# aquatopia betta care pack
# aquatopia
# aquatopia
# aquatopia
# ['Aquatopia','Betta','Care','Pack']
# aquatopia betta care pack
# pet pillow replacement dog bed cover to suit coolaroo medium pet bed
# pet pillow replac dog bed cover to suit coolaroo medium pet bed
# gazebos australia
# gazebos australia
# gazebo australia
# ['Pet','Pillow','Replacement','Dog','Bed','Cover','to','suit','Coolaroo','Medium','Pet','Bed']
# pet pillow replac dog bed cover to suit coolaroo medium pet bed
# grain free pure heaven biscuits
# grain free pure heaven biscuit
# canidae
# canidae
# canida
# ['canidae', 'color-duck-chickpea', 'dog biscuits', 'dog treat', 'dog-food', 'dog-gear', 'grain free', 'pet food', 'pure heaven', 'size-11-oz-bag', 'under-25']
# canida colorduckchickpea dog biscuit dog treat dogfood doggear grain free pet food pure heaven sizeozbag under
# temptations salmon flavour cat treats
# temptat salmon flavour cat treat
# temptations
# temptations
# temptat
# ['Baked', 'Biscuit', 'Brand_Temptations', 'cat-treats', 'Cats', 'Flavour_Salmon', 'JUNE2021', 'Pet Type_Cats', 'Salmon', 'temptations', 'Treat Type_Baked', 'Treat Type_Biscuit', 'under-25']
# bake biscuit brand temptat cattreat cat flavour salmon june pet type cat salmon temptat treat type bake treat type biscuit under
# party pup dog tag
# parti pup dog tag
# packed party
# packed party
# pack parti
# ['Accessories', 'Electric Dream', 'SPRING21']
# accessori electr dream spring
# pets dogs and cats cave bed parade
# pet dog and cat cave bed parad
# jobar
# jobar
# jobar
# ['cat caves', 'cat caves cozy cave pet bed', 'cave dog', 'cave pet bed', 'cozy cave dog bed', 'dog cave', 'dog cave bed', 'felted cat cave', 'pet cave', 'pet cave bed', 'snoozer cozy cave']
# cat cave cat cave cozi cave pet bed cave dog cave pet bed cozi cave dog bed dog cave dog cave bed felt cat cave pet cave pet cave bed snoozer cozi cave
# cat laser toys
# cat laser toy
# 8blue
# blue
# blue
# ['Automatic Cat Laser Toy', 'Cat Laser Toy', 'Haley', 'Interactive Laser Cat Toy', '打广告']
# automat cat laser toy cat laser toy haley interact laser cat toy 打广告
# designer waterproof reversible dog jacket
# design waterproof revers dog jacket
# zach's pet shop
# zachs pet shop
# zach pet shop
# ['Designer','Waterproof','Reversible','Dog','Jacket']
# design waterproof revers dog jacket
# roofle® maple flavor
# roofl mapl flavor
# redbarn
# redbarn
# redbarn
# ['Age_(0-12 months) Puppy/Kitten', 'Age_(1-2 years) Adolescent', 'Age_(3-8 years) Adult', 'Age_(8+ years) Senior', 'Chew Type_Light Chewer', 'Chew Type_Moderate Chewer', 'Chew Type_Power Chewer', 'Chews', 'Chews_Specialty', 'Dog', 'Dog Treats', 'Dog Treats: Chews', 'Dog Treats: Specialty', 'Focus_Boredom Busting', 'Focus_Dental Hygiene', 'FromWordpress', 'Maple', 'NetWeight-1.8oz (51 grams)', 'Size_(10 lbs or less) X-Small', 'Size_(11-25 lbs) Small', 'Size_(26-40 lbs) Medium', 'Size_(41-70 lbs) Large', 'Size_(71 lbs or more) X-Large', 'stockist-8870', 'Treats']
# age  month puppykitten age  year adolesc age  year adult age  year senior chew type light chewer chew type moder chewer chew type power chewer chew chew specialti dog dog treat dog treat chew dog treat specialti focu boredom bust focu dental hygien fromwordpress mapl netweightoz  gram size  lb or less xsmall size  lb small size  lb medium size  lb larg size  lb or more xlarg stockist treat
# personalized reflective dog collar with quick release buckle, embroidered
# person reflect dog collar with quick releas buckl embroid
# gotags
# gotags
# gotag
# ['Character Setting: Embroidered', 'Collar', 'collar - 25 char', 'Display Setting: Uppercase', 'Dog', 'Dog Collars', 'Personalized Dog Collars', 'Popular', 'Reflective Dog Collars', 'Type of Collar_Nylon', 'Type of Collar_Personalized', 'Type of Collar_Quick Release Snap', 'Type of Collar_Reflective']
# charact set embroid collar collar   char display set uppercas dog dog collar person dog collar popular reflect dog collar type of collar nylon type of collar person type of collar quick releas snap type of collar reflect
# section - ceramics pelco hideout & breeding
# section  ceram pelco hideout  breed
# fluxaqua
# fluxaqua
# fluxaqua
# ['Decorations', 'Normal']
# decor normal
# pawesome treat snowflakes
# pawesom treat snowflak
# pawesome treat
# pawesome treat
# pawesom treat
# ['Christmas', 'christmas2020', 'dog-treats', 'pawesome-treat', 'under-10']
# christma christma dogtreat pawesometreat under
# supreme bull stick
# suprem bull stick
# open range
# open range
# open rang
# ['BRAND_Open Range', 'FLAVOR_Beef', 'MADE IN_Canada', 'PRICE_$10.00 - $19.99', 'TYPE_Chew']
# brand open rang flavor beef made in canada price    type chew
# tytherton tweed boxy dog bed
# tytherton tweed boxi dog bed
# mutts and hounds
# mutts and hounds
# mutt and hound
# ['Tytherton','Tweed','Boxy','Dog','Bed']
# tytherton tweed boxi dog bed
# just fish cod skin dognip dog treats
# just fish cod skin dognip dog treat
# just fish
# just fish
# just fish
# ['Brand_Just Fish', 'Breed Size_All Sizes', 'Category_Dogs', 'Food Type_Treats', 'Life Stage_All Stages', 'Protein_Fish', 'Special Diet_By Product Free', 'Special Diet_Gluten Free', 'Special Diet_Grain Free', 'Special Diet_Limited Ingredient']
# brand just fish breed size all size categori dog food type treat life stage all stage protein fish special diet by product free special diet gluten free special diet grain free special diet limit ingredi
# bocce's bakery dailies menu soft & chewy treats
# bocc bakeri daili menu soft  chewi treat
# bocce's bakery
# bocces bakery
# bocc bakeri
# ['Dog Treats']
# dog treat
# mpets - wave ball cat toy
# mpet  wave ball cat toy
# petku
# petku
# petku
# ['Brand_MPETS', 'Category_Cats', 'cats', 'Lifestage_All lifestages', 'MPETS', 'Price_Rp 0 to Rp 100.000', 'Subcategory_Toys', 'Toys']
# brand mpet categori cat cat lifestag all lifestag mpet price rp  to rp  subcategori toy toy
# mighty rex monkey dog toy
# mighti rex monkey dog toy
# mighty rex
# mighty rex
# mighti rex
# ['25-50', 'Black', 'Brand_Mighty Rex', 'Colour_Black', 'Comfort', 'dog-toys', 'Dogs', 'JUNE2021', 'Material_Plush', 'Mighty Rex', 'Pet Type_Dogs', 'Plush', 'Puppy', 'Tough', 'Toy Type_Comfort', 'Toy Type_Puppy', 'Toy Type_Tough']
#  black brand mighti rex colour black comfort dogtoy dog june materi plush mighti rex pet type dog plush puppi tough toy type comfort toy type puppi toy type tough
# skamper ramp
# skamper ramp
# gamma2 .
# gamma
# gamma
# ['Dogs']
# dog
# goofy tails grooming hand brush for dog,small (color may vary)
# goofi tail groom hand brush for dogsmal color may vari
# goofy tails
# goofy tails
# goofi tail
# ['Adult (1 - 7 years)', 'Goofy Tails', 'Puppy ( 0 - 3 months)', 'Puppy ( 3-12 months)', 'Senior (7+ Years)', 'Shedding Control', 'woo_import_4']
# adult    year goofi tail puppi     month puppi   month senior  year shed control woo import
# rain paw waterproof all-season dog coat - navy blue
# rain paw waterproof allseason dog coat  navi blue
# gold paw
# gold paw
# gold paw
# ['Blue', 'Dog Coat', 'Waterproof']
# blue dog coat waterproof
# aquatopia half boat with horse head
# aquatopia half boat with hors head
# aquatopia
# aquatopia
# aquatopia
# ['Aquatopia','Half','Boat','with','Horse','Head']
# aquatopia half boat with hors head
# grain free cat food - freshly prepared turkey
# grain free cat food  freshli prepar turkey
# mypetsays
# mypetsays
# mypetsay
# ['Cat', 'Cat Food', 'Flavour_Turkey', 'Grain Free', 'Lifestage_Adult', 'Pet_Cat', 'Range_Grain Free']
# cat cat food flavour turkey grain free lifestag adult pet cat rang grain free
# squeakie buddie - bear
# squeaki buddi  bear
# zippy paws
# zippy paws
# zippi paw
# ['No-Stuffing', 'Plush', 'Squeakers']
# nostuf plush squeaker
# squeakie buddie - owl
# squeaki buddi  owl
# zippy paws
# zippy paws
# zippi paw
# ['Medium', 'No-Stuffing', 'Plush', 'Small', 'Squeakers']
# medium nostuf plush small squeaker
# matrixcarbon
# matrixcarbon
# seachem laboratories
# seachem laboratories
# seachem laboratori
# ['Fish']
# fish
# miniz popcorns
# miniz popcorn
# zippypaws
# zippypaws
# zippypaw
# ['BRAND_ZippyPaws', 'PET_Dogs', 'PRICE_$10.00 - $19.99', 'TYPE_Plush Toys']
# brand zippypaw pet dog price    type plush toy
# pawesome treat festive meaty strips
# pawesom treat festiv meati strip
# pawesome treat
# pawesome treat
# pawesom treat
# ['10-25', 'Christmas', 'christmas2020', 'dog-treats', 'pawesome-treat']
#  christma christma dogtreat pawesometreat
# dogphora anti-itch oatmeal and aloe with pleasant aroma shampoo
# dogphora antiitch oatmeal and alo with pleasant aroma shampoo
# dogphora
# dogphora
# dogphora
# ['PetSupplies']
# petsuppli
# giraffe knottie plush corduroy
# giraff knotti plush corduroy
# hugglehounds
# hugglehounds
# hugglehound
# ['Dogs']
# dog
# fresh 'n clean medi-clean medicated shampoo for dandruff, dermatitis and dry skin
# fresh n clean mediclean medic shampoo for dandruff dermat and dri skin
# fresh 'n clean
# fresh n clean
# fresh n clean
# ['PetSupplies']
# petsuppli
# repashy soilent green
# repashi soilent green
# repashy
# repashy
# repashi
# ['African Cichlid Food', 'Angelfish Food', 'brand_repashy', 'fish-food', 'fish-species_african-cichlid', 'fish-species_goldfish', 'Goldfish', 'Goldfish Food', 'meta-related-article-goldfish-food', 'meta-related-article-how-often-to-feed-fish', 'meta-related-article-repashy-gel-fish-food', 'Pleco Food', 'Repashy', 'Sinking Food', 'type_gel-food', 'type_sinking-food']
# african cichlid food angelfish food brand repashi fishfood fishspeci africancichlid fishspeci goldfish goldfish goldfish food metarelatedarticlegoldfishfood metarelatedarticlehowoftentofeedfish metarelatedarticlerepashygelfishfood pleco food repashi sink food type gelfood type sinkingfood
# braided bone orange
# braid bone orang
# tall tails
# tall tails
# tall tail
# ['BRAND_Tall Tails', 'PET_Dogs', 'PRICE_$20.00 - $29.99', 'TYPE_Interactive Toys']
# brand tall tail pet dog price    type interact toy
# airline anti-backflow check valve
# airlin antibackflow check valv
# fluxaqua
# fluxaqua
# fluxaqua
# ['Filtration', 'Normal']
# filtrat normal
# hamster/gerbil
# hamstergerbil
# oxbow
# oxbow
# oxbow
# ['BRAND_Oxbow', 'PRICE_$10.00 - $19.99', 'PRICE_$50.00 - $59.99', 'TYPE_Gerbil', 'TYPE_Hamster']
# brand oxbow price    price    type gerbil type hamster
# poochles classic puppy combo
# poochl classic puppi combo
# poochles
# poochles
# poochl
# ['Blue', 'Chew Control', 'Combo Product', 'Green', 'Imported', 'Indian', 'Leash And Collar Combo', 'Less than 1000', 'Less than 2000', 'Less than 500', 'Pink', 'Poochles', 'Puppy', 'Puppy Essentials Kit', 'Puppy Toys', 'Red', 'Rope Toys', 'Teething', 'Toy Combo', 'Treat Combo', 'Yellow']
# blue chew control combo product green import indian leash and collar combo less than  less than  less than  pink poochl puppi puppi essenti kit puppi toy red rope toy teeth toy combo treat combo yellow
# catnip botanicals lemongrass blend for cats
# catnip botan lemongrass blend for cat
# kong
# kong
# kong
# ['Adult Cats', 'Cat', 'Cat Treats', 'Catnip & Cat Grass', 'Kittens', 'Senior Cats']
# adult cat cat cat treat catnip  cat grass kitten senior cat
# japanese urashima taro costume
# japanes urashima taro costum
# always whiskered
# always whiskered
# alway whisker
# ['new-arrivals']
# newarriv
# cheese bites w garlic
# chees bite w garlic
# answers pet food
# answers pet food
# answer pet food
# ['BRAND_Answers Pet Food', 'FLAVOR_Cheese', 'PET_Dogs', 'PRICE_$10.00 - $19.99', 'TYPE_Raw Treat']
# brand answer pet food flavor chees pet dog price    type raw treat
# p.l.a.y barking brunch chicken and woofles plush toy for dogs
# play bark brunch chicken and woofl plush toy for dog
# p.l.a.y (ginger and bear)
# play ginger and bear
# play ginger and bear
# ['all-life-stages', 'brown', 'crinkle', 'day-5-of-christmas-flash', 'dog-plush', 'dog-plush-toys', 'dog-toys', 'eat-superfood-fix', 'fleece', 'machine-friendly', 'moderate-use', 'p-l-a-y', 'perrobox-link', 'play-heka', 'plush', 'puppia-play-sets', 'squeaky', 'toys', 'under-25', 'washable']
# alllifestag brown crinkl dayofchristmasflash dogplush dogplushtoy dogtoy eatsuperfoodfix fleec machinefriendli moderateus play perroboxlink playheka plush puppiaplayset squeaki toy under washabl
# cat pyramid bed with ball and scratcher
# cat pyramid bed with ball and scratcher
# pet cave co
# pet cave co
# pet cave co
# ['Cat Beds']
# cat bed
# pheasant launcher only
# pheasant launcher onli
# net2malls dropship
# netmalls dropship
# netmal dropship
# ['Remote Launchers']
# remot launcher
# firehose crayon red
# firehos crayon red
# zippypaws
# zippypaws
# zippypaw
# ['BRAND_ZippyPaws', 'PET_Dogs', 'PRICE_$10.00 - $19.99', 'TYPE_Plush Toys']
# brand zippypaw pet dog price    type plush toy
# treat rod refill for treat crunching toys
# treat rod refil for treat crunch toy
# starmark pet
# starmark pet
# starmark pet
# ['Dogs']
# dog
# fringe studio sombrero sloth on a rope dog squeaky plush toy
# fring studio sombrero sloth on a rope dog squeaki plush toy
# fringe studio (ginger and bear)
# fringe studio ginger and bear
# fring studio ginger and bear
# ['25-50', 'all', 'all-life-stages', 'dog', 'dog-plush', 'dog-plush-toys', 'dog-toys', 'easy-to-clean', 'fringe-studio', 'moderate-use', 'plush', 'polyester', 'squeaky', 'toys']
#  all alllifestag dog dogplush dogplushtoy dogtoy easytoclean fringestudio moderateus plush polyest squeaki toy
# kitty jungle gym
# kitti jungl gym
# kazoo pet co
# kazoo pet co
# kazoo pet co
# ['cat bed', 'Cat furniture', 'cat gymnasium', 'cat play gym', 'cat playground', 'cat tree', 'pet playground', 'scratch pole', 'scratch post']
# cat bed cat furnitur cat gymnasium cat play gym cat playground cat tree pet playground scratch pole scratch post
# dexas pets collapsible travel cup
# dexa pet collaps travel cup
# no
# no
# no
# ['$10 Tuesday Travel', '05062021-CH-Pets', 'Amazon USA', 'Animal Accessories', 'bowls', 'travel']
#  tuesday travel chpet amazon usa anim accessori bowl travel
# dog gate pet baby safety guard
# dog gate pet babi safeti guard
# global phoenix
# global phoenix
# global phoenix
# ['Price_$10 to $25', 'refund_fee:800']
# price  to  refund fee
# wellness petite soft mini bites lamb, apples & cinnamon dog treats
# well petit soft mini bite lamb appl  cinnamon dog treat
# wellness
# wellness
# well
# ['Brand_Wellness', 'Breed Size_Small', 'Category_Dogs', 'Food Type_Treats', 'Life Stage_All Stages', 'Protein_Lamb', 'Special Diet_Grain Free']
# brand well breed size small categori dog food type treat life stage all stage protein lamb special diet grain free
# beco strong starfish rough & tough dog toy
# beco strong starfish rough  tough dog toy
# beco
# beco
# beco
# ['Soft', 'Tough', 'Toys']
# soft tough toy
# kong tropics catnip fish teaser cat toy
# kong tropic catnip fish teaser cat toy
# kong
# kong
# kong
# ['Collections_Toys', 'Distributor_PFX', 'Species_Cat', 'Sub-Collection_Catnip Toys', 'Sub-Collection_Teaser Toys']
# collect toy distributor pfx speci cat subcollect catnip toy subcollect teaser toy
# rubber balloon dog toy
# rubber balloon dog toy
# pet clever
# pet clever
# pet clever
# ['Dog Toys', 'Dogs', 'rr_track_dogproducts', 'rr_track_dogtoys', 'Toys']
# dog toy dog rr track dogproduct rr track dogtoy toy
# peanut & carob
# peanut  carob
# twistix
# twistix
# twistix
# ['BRAND_Twistix', 'LIFE STAGE_All Life Stages', 'PET_Dogs', 'PRICE_$0.00 - $9.99', 'SPECIAL FORMULAS_Dental', 'TYPE_Crunchies']
# brand twistix life stage all life stage pet dog price    special formula dental type crunchi
# venison & okanagan apple
# venison  okanagan appl
# kettle craft
# kettle craft
# kettl craft
# ['BRAND_Kettle Craft', 'FLAVOR_Pork Liver', 'FLAVOR_Venison', 'PET_Dogs', 'PRICE_$0.00 - $9.99', 'PRICE_$10.00 - $19.99', 'TYPE_Soft']
# brand kettl craft flavor pork liver flavor venison pet dog price    price    type soft
# prevue pet kitty power paws hollywood chair
# prevu pet kitti power paw hollywood chair
# prevue pet products
# prevue pet products
# prevu pet product
# ['Cat Furniture', 'Hollywood Chair', 'Kitty', 'Power Paws', 'Prevue Pet Products']
# cat furnitur hollywood chair kitti power paw prevu pet product
# smart electric cat teasing toy
# smart electr cat teas toy
# pet clever
# pet clever
# pet clever
# ['Cat Toys', 'Cats', 'rr_track_catproducts', 'rr_track_cattoys']
# cat toy cat rr track catproduct rr track cattoy
# blackdog chicken necks
# blackdog chicken neck
# doggiebox
# doggiebox
# doggiebox
# ['Chicken', 'Dog', 'Poultry']
# chicken dog poultri
# the barkery dehydrated probiotic duck feet dog treats
# the barkeri dehydr probiot duck feet dog treat
# the barkery
# the barkery
# the barkeri
# ['Brand_The Barkery', 'Breed Size_All Sizes', 'Category_Dogs', 'Food Type_Treats', 'Life Stage_All Stages', 'Protein_Duck', 'Special Diet_By Product Free', 'Special Diet_Gluten Free', 'Special Diet_Grain Free']
# brand the barkeri breed size all size categori dog food type treat life stage all stage protein duck special diet by product free special diet gluten free special diet grain free
# chubleez sonny monkey dog toy
# chubleez sonni monkey dog toy
# rosewood
# rosewood
# rosewood
# ['colour-multi-coloured', 'Dog-toys', 'dogs', 'gifts', 'new-arrivals', 'play', 'puppy-toys', 'rosewood', 'senior-toys', 'soft-toys', 'toys']
# colourmulticolour dogtoy dog gift newarriv play puppytoy rosewood seniortoy softtoy toy
# oster cryogen-x pet clipper blades
# oster cryogenx pet clipper blade
# oster
# oster
# oster
# ['Shipped.io', 'trimmer supplies']
# shippedio trimmer suppli
# grumpy cat feather tail toy
# grumpi cat feather tail toy
# envon
# envon
# envon
# ['kellyville-pets', 'under-25']
# kellyvillepet under
# black isolation box with hooks
# black isol box with hook
# fluxaqua
# fluxaqua
# fluxaqua
# ['Accessories', 'Normal']
# accessori normal
# burns mini chicken & rice puppy
# burn mini chicken  rice puppi
# burns
# burns
# burn
# ['10-25', '25-50', 'burns', 'Coat', 'cyril', 'dog-food', 'Food Delivery', 'JANSALE18', 'Junior', 'Mini', 'Miniture', 'Natural', 'nonsale19', 'Puppy', 'puppy-food', 'size-2kg', 'size-6kg', 'Skin', 'Small', 'Small Breed', 'small-breed-food']
#   burn coat cyril dogfood food deliveri jansal junior mini minitur natur nonsal puppi puppyfood sizekg sizekg skin small small breed smallbreedfood
# hikari floating food sticks
# hikari float food stick
# hikari
# hikari
# hikari
# ['All Aquatic Products', 'Cichlid Pellets', 'Color Enhacing Food', 'Dry FW Foods', 'Floating Pellet', 'Hikari Dry Foods', 'Large Fish']
# all aquat product cichlid pellet color enhac food dri fw food float pellet hikari dri food larg fish
# valentine puppycake treats
# valentin puppycak treat
# paws gourmet
# paws gourmet
# paw gourmet
# ['gs']
# gs
# multi-functional cat climbing frame board scratching cattery mat toy
# multifunct cat climb frame board scratch catteri mat toy
# pet clever
# pet clever
# pet clever
# ['Cat Toys', 'Cats', 'meta-related-collection-cats', 'rr_track_catproducts', 'rr_track_cattoys']
# cat toy cat metarelatedcollectioncat rr track catproduct rr track cattoy
# ld dogtoy everplay supa'tug
# ld dogtoy everplay supatug
# pets home
# pets home
# pet home
# ['Brand_Pet Arabia', 'Category_Pets Home', 'Type_Pets Home']
# brand pet arabia categori pet home type pet home
# playtime palace cat furniture
# playtim palac cat furnitur
# ware
# ware
# ware
# ['20.000', '20wx20dx51h', '51.000', 'Cats', 'Furniture', 'Kitty Kouture']
#  wxdxh  cat furnitur kitti koutur
# ee toys chicken piece dog chew toy
# ee toy chicken piec dog chew toy
# euro pet
# euro pet
# euro pet
# ['Adult', 'Brown', 'Chennai', 'Chew Control', 'Chew Toys', 'Covid19', 'EE Toys', 'Imported', 'Less than 1000', 'Less than 2000', 'Less than 500', 'Nylon  Toys', 'Puppy', 'Teething']
# adult brown chennai chew control chew toy covid ee toy import less than  less than  less than  nylon toy puppi teeth
# rc funny wireless electronic remote control mouse mice rat pet toy for cats toys
# rc funni wireless electron remot control mous mice rat pet toy for cat toy
# ebay
# ebay
# ebay
# ['best remote control mice toy', 'controlled mouse cat toy', 'eBay Top Products', 'realistic remote control mouse', 'remote control cat toy', 'remote control rat']
# best remot control mice toy control mous cat toy ebay top product realist remot control mous remot control cat toy remot control rat
# couch cover for dogs and kids
# couch cover for dog and kid
# fetchworth
# fetchworth
# fetchworth
# ['dog accessories', 'sofa cover']
# dog accessori sofa cover
# zogoflex echo rumbl
# zogoflex echo rumbl
# west paw design
# west paw design
# west paw design
# ['Eco-Friendly Dog Toys', 'Floating Dog Toys', 'Interactive Dog Toys', 'Tough Dog Toys']
# ecofriendli dog toy float dog toy interact dog toy tough dog toy
# cat developmental toy hide-and-seek mouse tunnel toy
# cat development toy hideandseek mous tunnel toy
# pet clever
# pet clever
# pet clever
# ['Cat Toys', 'Cats', 'meta-related-collection-cats', 'rr_track_catproducts', 'rr_track_cattoys']
# cat toy cat metarelatedcollectioncat rr track catproduct rr track cattoy
# ecru linen dog bed
# ecru linen dog bed
# the linen works
# the linen works
# the linen work
# ['cat:cushions & throws', 'natural', 'personalise', 'sam test']
# catcushion  throw natur personalis sam test
# padlock pet id tag
# padlock pet id tag
# hamish mcbeth
# hamish mcbeth
# hamish mcbeth
# ['Pet ID Tags']
# pet id tag
# mutant animal seapork dog toy
# mutant anim seapork dog toy
# zee.dog
# zeedog
# zeedog
# ['Adult Dogs', 'Dog', 'Dog Toys', 'Puppies', 'Senior Dogs', 'Toy', 'Toys']
# adult dog dog dog toy puppi senior dog toy toy
# gg laser mouse cat toy
# gg laser mous cat toy
# good girl
# good girl
# good girl
# ['GG','Laser','Mouse','Cat','Toy']
# gg laser mous cat toy
# the jolly flyer frisbee disc
# the jolli flyer frisbe disc
# jolly pets
# jolly pets
# jolli pet
# ['Disc', 'Endurance', 'Fetch', 'Jolly Pets', 'Toy']
# disc endur fetch jolli pet toy
# tree frog ropetugz dog toy
# tree frog ropetugz dog toy
# pawsitive vibes
# pawsitive vibes
# pawsit vibe
# ['animal', 'birthday gift', 'christmas gift', 'cute stuff for dogs', 'cute toys', 'dog', 'dog gifts', 'dog toy', 'dog toys', 'Doggie Toys', 'doggy toy', 'doy toys', 'fun toy', 'rope toy for dog', 'ropetugz', 'toy', 'toys', 'toys for dogs']
# anim birthday gift christma gift cute stuff for dog cute toy dog dog gift dog toy dog toy doggi toy doggi toy doy toy fun toy rope toy for dog ropetugz toy toy toy for dog
# rabbit squeaker
# rabbit squeaker
# tall tails
# tall tails
# tall tail
# ['BRAND_Tall Tails', 'PET_Dogs', 'PRICE_$20.00 - $29.99', 'TYPE_Plush Toys']
# brand tall tail pet dog price    type plush toy
# pawz pet cat tree scratching post scratcher trees pole gym condo home furniture
# pawz pet cat tree scratch post scratcher tree pole gym condo home furnitur
# unbranded
# unbranded
# unbrand
# ['AU', 'dogscats', 'NewArrivals', 'petsupplies', 'SELL38', 'toystreats']
# au dogscat newarriv petsuppli sell toystreat
# collapsible brown s-shaped cat tunnel play toy
# collaps brown sshape cat tunnel play toy
# pet clever
# pet clever
# pet clever
# ['Best Sellers', 'Cat Toys', 'Cats', 'meta-related-collection-cats', 'rr_track_catproducts', 'rr_track_cattoys']
# best seller cat toy cat metarelatedcollectioncat rr track catproduct rr track cattoy
# nerf dog pro grip squeak football
# nerf dog pro grip squeak footbal
# nerf
# nerf
# nerf
# ['All Dog Products', 'All Dog Toys', 'Fetch Toys', 'Interactive Toys', 'Squeak Toys', 'Water Dogs']
# all dog product all dog toy fetch toy interact toy squeak toy water dog
# dr. harvey's sweet potato'r chews
# dr harvey sweet potat chew
# dr. harvey's
# dr harveys
# dr harvey
# ['Treats & Chews']
# treat  chew
# dehydrated beef formula dog food (verve)
# dehydr beef formula dog food verv
# the honest kitchen
# the honest kitchen
# the honest kitchen
# ['New']
# new
# crab dog toy molar stick chew-resistant toothbrush
# crab dog toy molar stick chewresist toothbrush
# pincrowdniche
# pincrowdniche
# pincrowdnich
# ['cj', 'ds', 'fc', 's']
# cj ds fc s
# smartykat tassel and ball thwapper teaser cat toy
# smartykat tassel and ball thwapper teaser cat toy
# smartykat
# smartykat
# smartykat
# ['Adult', 'Cat Toys', 'Catnip Toys', 'flitz', 'Green', 'Less than 1000', 'Less than 2000', 'Less than 500', 'Marketing', 'Smartykat']
# adult cat toy catnip toy flitz green less than  less than  less than  market smartykat
# bingo cat teasing toy replacement
# bingo cat teas toy replac
# petkit
# petkit
# petkit
# ['Adult Cats', 'Cat', 'Kittens', 'Senior Cats', 'Toys']
# adult cat cat kitten senior cat toy
# soon to be a big brother - dog bandana
# soon to be a big brother  dog bandana
# spod
# spod
# spod
# ['Accessories', 'Bandanas', 'Daisy/Tinh/DS', 'Dog', 'Dog Bandana', 'fathers day', 'non-custom', 'Pet Bandana', 'recommendation disable', 'Rosie/Hong/PR', 'Sarah/Suong/PS', 'SPOD', 'thank-you-page']
# accessori bandana daisytinhd dog dog bandana father day noncustom pet bandana recommend disabl rosiehongpr sarahsuongp spod thankyoupag
# premium boxer dog reflective harness
# premium boxer dog reflect har
# ploocy
# ploocy
# plooci
# ['boxer', 'harness', 'reflective']
# boxer har reflect
# the emperor foldable cat house
# the emperor foldabl cat hous
# sneaky whiskers
# sneaky whiskers
# sneaki whisker
# ['The','Emperor','Foldable','Cat','House']
# the emperor foldabl cat hous
# ornament coral australian branch - green
# ornament coral australian branch  green
# blue fish aquarium
# blue fish aquarium
# blue fish aquarium
# ['All Aquatic Products', 'Aquarium Ornaments', 'Artificial Corals']
# all aquat product aquarium ornament artifici coral
# cat hat costume bundle
# cat hat costum bundl
# meowingtons
# meowingtons
# meowington
# ['accessories', 'cat', 'cat costume', 'cat hat', 'cat hat costume', 'Cat toy', 'cats', 'christmas cat costume', 'christmas costume', 'Costume', 'Costumes', 'cottagecore', 'cute cat toy', 'cute halloween', 'frog', 'frog hat', 'frog hat for cats', 'halloween', 'halloween cat', 'halloween cat toy', 'halloween cats', 'halloween costume', 'handmade', 'hat for cat', 'made in usa', 'toad hat', 'usa']
# accessori cat cat costum cat hat cat hat costum cat toy cat christma cat costum christma costum costum costum cottagecor cute cat toy cute halloween frog frog hat frog hat for cat halloween halloween cat halloween cat toy halloween cat halloween costum handmad hat for cat made in usa toad hat usa
# jbj protein skimmer
# jbj protein skimmer
# jbj
# jbj
# jbj
# ['Regular Price']
# regular price
# beach balls dog collar
# beach ball dog collar
# threaded pear
# threaded pear
# thread pear
# ['animal:dog']
# animaldog
# squeakie pad - pig
# squeaki pad  pig
# zippy paws
# zippy paws
# zippi paw
# ['Medium', 'No-Stuffing', 'Plush', 'Small', 'Squeakers']
# medium nostuf plush small squeaker
# martingale cinch collar
# martingal cinch collar
# mighty paw
# mighty paw
# mighti paw
# ['Collars', 'freemartingale_onlyshipping', 'Training']
# collar freemartingal onlyship train
# canada birch dove grey dog bed - in store only
# canada birch dove grey dog bed  in store onli
# canada pooch
# canada pooch
# canada pooch
# ['Canada Pooch', 'In Store Only Bed']
# canada pooch in store onli bed
# loomy green monster
# loomi green monster
# bud'z
# budz
# budz
# ["BRAND_Bud'z", 'PET_Dogs', 'PRICE_$10.00 - $19.99', 'TYPE_Plush Toys']
# brand budz pet dog price    type plush toy
# pawesome treat lets pawty!
# pawesom treat let pawti
# pawesome treat
# pawesome treat
# pawesom treat
# ['10-25', 'dog-treats', 'pawesome-treat']
#  dogtreat pawesometreat
# biteables digestive health plus functional cat soft treats
# biteabl digest health plu function cat soft treat
# get naked
# get naked
# get nake
# ['cat', 'corn free', 'digestive health', 'functional', 'get naked', 'grain free', 'gut health', 'low calorie', 'soft', 'soy free', 'wheat free']
# cat corn free digest health function get nake grain free gut health low calori soft soy free wheat free
# bowsers thyme microvelvet double donut dog bed
# bowser thyme microvelvet doubl donut dog bed
# bowsers
# bowsers
# bowser
# ['Bowsers Beds', 'Donut Dog Beds', 'Gray', 'L', 'Large Dog Beds', 'M', 'Round', 'S', 'Small Dog Beds', 'Under $200', 'Under $250', 'Under $500', 'XL']
# bowser bed donut dog bed gray l larg dog bed m round s small dog bed under  under  under  xl
# blue seal entrust senior chicken meal & barley recipe
# blue seal entrust senior chicken meal  barley recip
# blue seal feeds
# blue seal feeds
# blue seal feed
# ['Brand_Blue Seal', 'Category_Dog Food', 'Dog', 'Flavor_Chicken', 'Food Type_Dry Dog Food', 'Life Stage_Senior']
# brand blue seal categori dog food dog flavor chicken food type dri dog food life stage senior
# multipet furry mice
# multipet furri mice
# multipet
# multipet
# multipet
# ['Cat', 'hand-selected', 'Multipet', 'Online', 'Phillips', 'show-tag-hand-selected', 'show-tag-occupy', 'Up to $25 Value', 'Up tp $25 Value']
# cat handselect multipet onlin phillip showtaghandselect showtagoccupi up to  valu up tp  valu
# kittos cat sunfish & chicken twirls
# kitto cat sunfish  chicken twirl
# kittos
# kittos
# kitto
# ['Cat Treats', 'Chicken', 'Fish', 'Less than 1000', 'Less than 2000', 'Less than 250', 'Less than 500']
# cat treat chicken fish less than  less than  less than  less than
# ken's ultra spirulina garlic & paprika flake
# ken ultra spirulina garlic  paprika flake
# ken's
# kens
# ken
# ['kens ultra', 'spirulina garlic paprika flake']
# ken ultra spirulina garlic paprika flake
# squeakie emojiz™ - cool dude
# squeaki emojiz  cool dude
# zippy paws
# zippy paws
# zippi paw
# ['Plush', 'Sale', 'Squeakers', 'Stuffing']
# plush sale squeaker stuf
# chicken chewsticks - yellow
# chicken chewstick  yellow
# petstreet online
# petstreet online
# petstreet onlin
# ['Chewables', 'Other']
# chewabl other
# bone shape silent silicone dog tags
# bone shape silent silicon dog tag
# gotags
# gotags
# gotag
# ['_options: COL', 'Character Setting: Engraved', 'Dog', 'Material_Silicone', 'Pet Tags', 'Popular', 'Silent Pet Tags', 'Silicone Pet Tags', 'Tag', 'Tag Shape_Bone', 'Type of Tag_Colorful', 'Type of Tag_Silent']
# option col charact set engrav dog materi silicon pet tag popular silent pet tag silicon pet tag tag tag shape bone type of tag color type of tag silent
# pink camo no-stink waterproof collar
# pink camo nostink waterproof collar
# wilderpup
# wilderpup
# wilderpup
# ['camo', 'FAIRE', 'Wilderpup']
# camo fair wilderpup
# redline science straight hemostats
# redlin scienc straight hemostat
# pangea
# pangea
# pangea
# ['Redline','Science','Straight','Hemostats']
# redlin scienc straight hemostat
# pets check iced cool mat cushion pet supplies summer new
# pet check ice cool mat cushion pet suppli summer new
# cald
# cald
# cald
# ['Pets','Check','iced','cool','mat','Cushion','Pet','Supplies','Summer','New']
# pet check ice cool mat cushion pet suppli summer new
# repashy super green
# repashi super green
# repashy
# repashy
# repashi
# ['brand_repashy', 'fish-food', 'meta-related-article-repashy-gel-fish-food', 'Repashy', 'type_gel-food']
# brand repashi fishfood metarelatedarticlerepashygelfishfood repashi type gelfood
# treatworx cod bites
# treatworx cod bite
# treatworx
# treatworx
# treatworx
# ['Treatworx']
# treatworx
# zee.cat finger puppets
# zeecat finger puppet
# zee.dog
# zeedog
# zeedog
# ['Adult Cats', 'Cat', 'Cat Toy', 'Kittens', 'Senior Cats', 'Toys']
# adult cat cat cat toy kitten senior cat toy
# wibbleez short
# wibbleez short
# spunky pup
# spunky pup
# spunki pup
# ['BRAND_Spunky Pup', 'PET_Dogs', 'PRICE_$10.00 - $19.99', 'TYPE_Interactive Toys']
# brand spunki pup pet dog price    type interact toy
# hide n seek - strawberry pawky sticks dog toy
# hide n seek  strawberri pawki stick dog toy
# hey cuzzies
# hey cuzzies
# hey cuzzi
# ['Adult Dogs', 'Dog', 'Dog Toys', 'Puppies', 'Senior Dogs', 'Toys']
# adult dog dog dog toy puppi senior dog toy
# mouth spray dog breath clear
# mouth spray dog breath clear
# kenko
# kenko
# kenko
# ['Adult Dogs', 'Dog', 'Grooming', 'Puppies', 'Senior Dogs']
# adult dog dog groom puppi senior dog
# get outside hiking boot - refillable dogginip® toy by smarterpaw™
# get outsid hike boot  refil dogginip toy by smarterpaw
# doggijuana
# doggijuana
# doggijuana
# ['Get Outside', 'Large', 'Medium', 'Small']
# get outsid larg medium small
# rascals treat's - top dog
# rascal treat  top dog
# hillview farms
# hillview farms
# hillview farm
# ['Dog Treats']
# dog treat
# wrapped backstrap
# wrap backstrap
# open range
# open range
# open rang
# ['BRAND_Open Range', 'FLAVOR_Beef', 'MADE IN_Canada', 'PRICE_$0.00 - $9.99', 'PRICE_$10.00 - $19.99', 'TYPE_Chew']
# brand open rang flavor beef made in canada price    price    type chew
# whiteout oreo zulu african fat tail gecko
# whiteout oreo zulu african fat tail gecko
# tikisgeckos
# tikisgeckos
# tikisgecko
# ['african fat tail', 'african fat tail gecko']
# african fat tail african fat tail gecko
# living world stoplight with balls
# live world stoplight with ball
# living world
# living world
# live world
# ['Animal-Birds', 'Department-Toys', 'ProductType-Bird Toys']
# animalbird departmenttoy producttypebird toy
# portable foldable pet playpen for dogs cats other pets
# portabl foldabl pet playpen for dog cat other pet
# global phoenix
# global phoenix
# global phoenix
# ['Color_Blue', 'Color_Brown', 'Color_Pink', 'Price_$25 to $50', 'refund_fee:1200']
# color blue color brown color pink price  to  refund fee
# disposable diapers
# dispos diaper
# pet edge
# pet edge
# pet edg
# ['gs']
# gs
# dog is good inspired rubber ball
# dog is good inspir rubber ball
# pet arabia
# pet arabia
# pet arabia
# ['Brand_Pet Arabia', 'Category_Toys', 'Type_Pet Supplies']
# brand pet arabia categori toy type pet suppli
# plush fruit pet toy
# plush fruit pet toy
# the pet hut
# the pet hut
# the pet hut
# ['Christmas Gifts for Pets', 'Dog Toy', 'New', 'Pet', 'Pet Care', 'Plush Dog Toy', 'Plush Dog Toys', 'Soft Dog Toy', 'Soft Dog Toys']
# christma gift for pet dog toy new pet pet care plush dog toy plush dog toy soft dog toy soft dog toy
# weruva seafood & eat it! variety pack cat food cans
# weruva seafood  eat it varieti pack cat food can
# weruva
# weruva
# weruva
# ['Brand_Weruva', 'Cat', 'Category_Cat Food', 'Flavor_Fish', 'Food Type_Wet Cat Food', 'Life Stage_All']
# brand weruva cat categori cat food flavor fish food type wet cat food life stage all
# merrick dog food grain free large breed chicken & sweet potato
# merrick dog food grain free larg breed chicken  sweet potato
# merrick
# merrick
# merrick
# ['Flat Rate Shipping', 'Free Shipping', 'Grain Free', 'Large Breed', 'Merrick']
# flat rate ship free ship grain free larg breed merrick
# bowsers ritz microvelvet double donut dog bed
# bowser ritz microvelvet doubl donut dog bed
# bowsers
# bowsers
# bowser
# ['Black', 'Bowsers Beds', 'Donut Dog Beds', 'L', 'Large Dog Beds', 'M', 'Round', 'S', 'Small Dog Beds', 'Under $200', 'Under $250', 'Under $500', 'XL']
# black bowser bed donut dog bed l larg dog bed m round s small dog bed under  under  under  xl
# heeyoo nonslip car dog steps portable metal frame large lightweight folding
# heeyoo nonslip car dog step portabl metal frame larg lightweight fold
# heeyoo
# heeyoo
# heeyoo
# ['Dogs', 'Open-Box']
# dog openbox
# sailor boy dog tank - blue
# sailor boy dog tank  blue
# dogo
# dogo
# dogo
# ['Blue', 'Dog Apparel', 'Dog Shirts', 'Dogo', 'L', 'M', 'S', 'Under $100', 'Under $150', 'Under $200', 'Under $250', 'Under $50', 'Under $75', 'XL', 'XS', 'XXL', 'XXS']
# blue dog apparel dog shirt dogo l m s under  under  under  under  under  under  xl xs xxl xx
# cat bells
# cat bell
# pets home
# pets home
# pet home
# ['Brand_Pet Arabia', 'Category_Pets Home', 'Type_Pets Home']
# brand pet arabia categori pet home type pet home
# round pet lounger cushion
# round pet lounger cushion
# cap point
# cap point
# cap point
# ['Round','Pet','Lounger','Cushion']
# round pet lounger cushion
# eledump | dog toy
# eledump  dog toy
# zee.dog
# zeedog
# zeedog
# ['active', 'bf_4_toys_20', 'cm_30', 'cm_sale', 'color_orange', 'new-product-page', 'Squeak', 'Toys', 'type:plush_toy']
# activ bf  toy  cm  cm sale color orang newproductpag squeak toy typeplush toy
# tuna & turkey filet entrée
# tuna  turkey filet entré
# redbarn
# redbarn
# redbarn
# ['Age_(0-12 months) Puppy/Kitten', 'Age_(1-2 years) Adolescent', 'Age_(3-8 years) Adult', 'Age_(8+ years) Senior', 'Cat', 'Cat Food', 'Cat Food: Filets', 'Chew Type_Light Chewer', 'Chew Type_Moderate Chewer', 'Chew Type_Power Chewer', 'Filets', 'Flavor_Tuna', 'Flavor_Turkey', 'Focus_Functional Ingredients', 'Food', 'FromWordpress', 'Hydration', 'Large (15-25 lbs)', 'Medium (8-14 lbs)', 'NetWeight-2.8oz', 'Preference_Grain-Free', 'Preference_No Rawhide', 'Product Size_2.8oz', 'Rewards', 'Small (3-7 lbs)', 'stockist-8870', 'X-Large (More than 25 lbs)', 'X-Small (Less than 3 lbs)']
# age  month puppykitten age  year adolesc age  year adult age  year senior cat cat food cat food filet chew type light chewer chew type moder chewer chew type power chewer filet flavor tuna flavor turkey focu function ingredi food fromwordpress hydrat larg  lb medium  lb netweightoz prefer grainfre prefer no rawhid product size oz reward small  lb stockist xlarg more than  lb xsmall less than  lb
# z-stitch® grunterz - manny the mammoth
# zstitch grunterz  manni the mammoth
# zippy paws
# zippy paws
# zippi paw
# ['large', 'Medium', 'Plush', 'Small', 'Squeakers', 'Stuffing', 'Tough']
# larg medium plush small squeaker stuf tough
# diy personalised dreamcatcher activity kit - sea animal
# diy personalis dreamcatch activ kit  sea anim
# doxbox store
# doxbox store
# doxbox store
# ['DIY','personalised','dreamcatcher','activity','kit','-','Sea','animal']
# diy personalis dreamcatch activ kit  sea anim
# fluval accent cabinet stand black
# fluval accent cabinet stand black
# fluval
# fluval
# fluval
# ['Fluval','Accent','Cabinet','Stand','Black']
# fluval accent cabinet stand black
# burgess supadog chicken
# burgess supadog chicken
# burgess
# burgess
# burgess
# ['10-25', 'Adult', 'burgess', 'Coat', 'dog-food', 'Food Delivery', 'JANSALE18', 'Natural', 'nonsale19', 'size-15kg', 'Skin']
#  adult burgess coat dogfood food deliveri jansal natur nonsal sizekg skin
# itent cat tent for indoor outdoor enclosures playpen x large portable black
# itent cat tent for indoor outdoor enclosur playpen x larg portabl black
# itent
# itent
# itent
# ['Cats', 'Open-Box']
# cat openbox
# ruff dawg football flyer retrieving dog toy
# ruff dawg footbal flyer retriev dog toy
# ruff dawg (perromart)
# ruff dawg perromart
# ruff dawg perromart
# ['14-90-deals', '325-deals', 'all', 'all-life-stages', 'balls-and-fetch', 'best-toys-for-dogs-and-cats', 'dog', 'dog-balls-and-fetch', 'dog-toys', 'easy-to-clean', 'exclusive-deals', 'exclusive-products', 'floatable', 'high-GM', 'label-1-up-to-55%-off', 'last-chance-to-get', 'multi', 'new-arrivals-dog-cat', 'new-in', 'price-reduced', 'promo', 'rough-use', 'rubber', 'ruff-dawg', 'ruffdawg-16-series', 'toys', 'under-25']
# deal deal all alllifestag ballsandfetch besttoysfordogsandcat dog dogballsandfetch dogtoy easytoclean exclusived exclusiveproduct floatabl highgm labeluptooff lastchancetoget multi newarrivalsdogcat newin pricereduc promo roughus rubber ruffdawg ruffdawgseri toy under
# electric rolling laser ball pet toy
# electr roll laser ball pet toy
# pet clever
# pet clever
# pet clever
# ['Cat Toys', 'Cats', 'Dogs', 'rr_track_catproducts', 'rr_track_cattoys', 'rr_track_dogproducts', 'rr_track_dogtoys']
# cat toy cat dog rr track catproduct rr track cattoy rr track dogproduct rr track dogtoy
# goofy tails flavored ball with holes rubber chew toy
# goofi tail flavor ball with hole rubber chew toy
# goofy tails
# goofy tails
# goofi tail
# ['Adult (1 - 7 years)', 'Ball', 'Chew Toys', 'Flying and Fetch', 'Large ( 20-40 kgs)', 'Medium ( 10-20 kgs)', 'Natural Rubber', 'Puppy ( 3-12 months)', 'Senior (7+ Years)', 'Small ( 5-10 kgs)', 'woo_import_4', 'X-Small ( 0-5 kgs)']
# adult    year ball chew toy fli and fetch larg   kg medium   kg natur rubber puppi   month senior  year small   kg woo import  xsmall   kg
# illuminated nail clipper
# illumin nail clipper
# comfures
# comfures
# comfur
# ['pet']
# pet
# rainbow with paws - pet waste poop bags + free dispenser
# rainbow with paw  pet wast poop bag  free dispens
# downtown pet supply
# downtown pet supply
# downtown pet suppli
# ['Best Sellers', 'Best Selling Items', 'Clean up', 'dog poop bags', 'dog poop pick up bags', 'Dogs', 'Hot Items', 'Pet Waste Bags', 'pick up poop bags', 'poop bags', 'price:1', 'price:2']
# best seller best sell item clean up dog poop bag dog poop pick up bag dog hot item pet wast bag pick up poop bag poop bag price price
# bowsers athena grey microvelvet donut dog bed
# bowser athena grey microvelvet donut dog bed
# bowsers
# bowsers
# bowser
# ['Bowsers Beds', 'Gray', 'L', 'Large Dog Beds', 'M', 'Medium Dog Beds', 'Round', 'S', 'Small Dog Beds', 'Under $100', 'Under $150', 'Under $200', 'Under $250', 'Under $500', 'Under $75', 'XL', 'XS', 'XXL']
# bowser bed gray l larg dog bed m medium dog bed round s small dog bed under  under  under  under  under  under  xl xs xxl
# ken's premium vitamin booster flake
# ken premium vitamin booster flake
# worldwide
# worldwide
# worldwid
# ['fish food', 'flake food', 'kens', 'kens premium', 'vitamin booster flake']
# fish food flake food ken ken premium vitamin booster flake
# alligator crochet dog toy with squeaker
# allig crochet dog toy with squeaker
# dogo
# dogo
# dogo
# ['Dogo', 'Green', 'Plush Toys', 'S', 'Squeaky Toys', 'Under $100', 'Under $150', 'Under $200', 'Under $25', 'Under $250', 'Under $50', 'Under $500', 'Under $75', 'XS']
# dogo green plush toy s squeaki toy under  under  under  under  under  under  under  under  xs
# bowsers tucson microlinen double donut dog bed
# bowser tucson microlinen doubl donut dog bed
# bowsers
# bowsers
# bowser
# ['Bowsers Beds', 'Donut Dog Beds', 'L', 'Large Dog Beds', 'M', 'Orange', 'Round', 'S', 'Small Dog Beds', 'Under $200', 'Under $250', 'Under $500', 'XL']
# bowser bed donut dog bed l larg dog bed m orang round s small dog bed under  under  under  xl
# dental functional dog treats
# dental function dog treat
# mypetsays
# mypetsays
# mypetsay
# ['Adult', 'Dental', 'Dog', 'Dog Treats', 'Flavour_Turkey', 'Grain Free', 'Lifestage_Adult', 'Pet_Dog', 'Range_Grain Free']
# adult dental dog dog treat flavour turkey grain free lifestag adult pet dog rang grain free
# grumpy cat cat toy with catnip
# grumpi cat cat toy with catnip
# grumpy cat
# grumpy cat
# grumpi cat
# ['cats', 'colour-brown', 'gifts', 'grumpy-cat', 'play', 'toys']
# cat colourbrown gift grumpycat play toy
# bowsers herringbone microvelvet double donut dog bed
# bowser herringbon microvelvet doubl donut dog bed
# bowsers
# bowsers
# bowser
# ['Bowsers Beds', 'Brown', 'Donut Dog Beds', 'L', 'Large Dog Beds', 'M', 'Round', 'S', 'Small Dog Beds', 'Under $200', 'Under $250', 'Under $500', 'XL']
# bowser bed brown donut dog bed l larg dog bed m round s small dog bed under  under  under  xl
# okocat soft step natural wood clumping cat litter
# okocat soft step natur wood clump cat litter
# okocat
# okocat
# okocat
# ['Biodegradable', 'Brand_Okocat', 'Cat', 'Cat Litter', 'Cat Supplies', 'Category_Clumping', 'Category_Flushable', 'Category_Lightweight', 'Category_Unscented', 'Litter Material_Wood', 'Odor Control', 'Price_$10 to $20', 'Price_$20 to $30', 'Price_$30 to $40', 'Product weight_10-15 lbs', 'Product weight_5-10 lbs']
# biodegrad brand okocat cat cat litter cat suppli categori clump categori flushabl categori lightweight categori unscent litter materi wood odor control price  to  price  to  price  to  product weight  lb product weight  lb
# cheshire cat id tag with swarovski crystals
# cheshir cat id tag with swarovski crystal
# gotags
# gotags
# gotag
# ['Cat', 'Character Setting: Engraved', 'Crystal Pet Tags', 'Material_Stainless Steel', 'Pet Tags', 'Stainless Steel Pet Tags', 'Tag', 'Tag Shape_Round', 'Type of Tag_Crystal', 'Unique Pet Tags']
# cat charact set engrav crystal pet tag materi stainless steel pet tag stainless steel pet tag tag tag shape round type of tag crystal uniqu pet tag
# durable pet chew toy
# durabl pet chew toy
# euro pet
# euro pet
# euro pet
# ['Chew Control', 'Chew Toys', 'Covid19', 'Indian', 'Less than 1000', 'Less than 2000', 'Less than 250', 'Less than 500', 'Puppy', 'Puppy Toys', 'Rubber Toys', 'Smarty Pet', 'Teething']
# chew control chew toy covid indian less than  less than  less than  less than  puppi puppi toy rubber toy smarti pet teeth
# goli design spurli whirli cat nip toy
# goli design spurli whirli cat nip toy
# goli design
# goli design
# goli design
# ['Brand_Goli Design', 'Collection-Cat Toys', 'Not Currently Stocked', 'Toy Type_Catnip', 'Toy Type_Rattle', 'TWR']
# brand goli design collectioncat toy not current stock toy type catnip toy type rattl twr
# ee toys frisbee shaped dog chew toy
# ee toy frisbe shape dog chew toy
# euro pet
# euro pet
# euro pet
# ['20% off Toys', 'Adult', 'Chennai', 'Chew Toys', 'Covid19', 'EE Toys', 'Fetch', 'flitz', 'Indian', 'Less than 1000', 'Less than 2000', 'Marketing', 'Poochles+', 'Puppy', 'Puppy Toys', 'Rubber Toys', 'Yellow']
#  off toy adult chennai chew toy covid ee toy fetch flitz indian less than  less than  market poochl puppi puppi toy rubber toy yellow
# northwest naturals pork liver freeze dried treats for dogs and cats
# northwest natur pork liver freez dri treat for dog and cat
# northwest naturals
# northwest naturals
# northwest natur
# ['Brand_Northwest Naturals', 'Collection-Cat Treats', 'Dietary Need_Grain Free', 'Dietary Need_Limited Ingredient', 'Primary Protein_Pork', 'Raw Rewards', 'Treat Type_Freeze Dried', 'TWR']
# brand northwest natur collectioncat treat dietari need grain free dietari need limit ingredi primari protein pork raw reward treat type freez dri twr
# stella & chewy’s crav’n bac’n bites (bacon & duck) recipe dog treats
# stella  chewi cravn bacn bite bacon  duck recip dog treat
# stella & chewy's
# stella  chewys
# stella  chewi
# ["Brand_Stella & Chewy's", 'Breed Size_All Sizes', 'Category_Dogs', 'Food Type_Treats', 'Life Stage_All Stages', 'Protein_Pork & Duck', 'Special Diet_By Product Free', 'Special Diet_Gluten Free', 'Special Diet_Grain Free']
# brand stella  chewi breed size all size categori dog food type treat life stage all stage protein pork  duck special diet by product free special diet gluten free special diet grain free
# ...
# siku
# siku
# siku
# ['$0 to $25', 'boys', 'construction-themed', 'construction-toys', 'construction-vehicles', 'diecast-models', 'gift-finder', 'gift-wrap', 'junior-schoolers', 'preschoolers', 'shopall', 'siku', 'stocking-fillers', 'truck', 'trucks', 'unisex', 'vehicles']
#  to  boy constructionthem constructiontoy constructionvehicl diecastmodel giftfind giftwrap juniorschool preschool shopal siku stockingfil truck truck unisex vehicl
# o'neal matrix afterburner glovers black/white
# oneal matrix afterburn glover blackwhit
# o'neal
# oneal
# oneal
# ['Normal']
# normal
# life feeds on life sticker
# life feed on life sticker
# crooked creek holler
# crooked creek holler
# crook creek holler
# ['import_2021_10_07_152238', 'Stickers']
# import     sticker
# traffic signs
# traffic sign
# fun factory
# fun factory
# fun factori
# ['10-to-25', 'cars', 'fun-factory', 'junior-schoolers', 'middle-schoolers', 'preschoolers', 'road-signs', 'road-traffic-signs', 'vehicles', 'wooden-vehicles']
# to car funfactori juniorschool middleschool preschool roadsign roadtrafficsign vehicl woodenvehicl
# double suspension bridge
# doubl suspens bridg
# brio
# brio
# brio
# ['3-4 Years', '5-7 Years', 'brio', 'Building', 'Construction', 'low stock', 'out of stock', 'Planes and Drones', 'Playsets-Racetracks_Wooden playsets', 'Playsets-Racetracks_Wooden trains', 'playsets_racetracks_', 'Preschool', 'Preschool_Trains', 'Preschool_Trains and Vehicles', 'Preschool_Trains and Vehicles_', 'Shop Toys', 'Shop_Preschool', 'Shop_Preschools', 'Shop_Toys', 'Shop_Trains', 'Shop_Vehicles', 'Train', 'Trains', 'trains_vehicles', 'vehicles', 'vehicles_trains', 'Vehicles_Trains_Playsets and Racetracks', 'Vehicles_Trains_Trains', 'Vehicles_Trains_Wooden trains', 'wooden trains']
#  year  year brio build construct low stock out of stock plane and drone playsetsracetrack wooden playset playsetsracetrack wooden train playset racetrack preschool preschool train preschool train and vehicl preschool train and vehicl shop toy shop preschool shop preschool shop toy shop train shop vehicl train train train vehicl vehicl vehicl train vehicl train playset and racetrack vehicl train train vehicl train wooden train wooden train
# international trucks diamond plate license
# intern truck diamond plate licens
# international harvester
# international harvester
# intern harvest
# ['decor', 'home', 'International Truck', 'metal', 'neon', 'novelty', 'Sign']
# decor home intern truck metal neon novelti sign
# scale: n - jaguar ss sedan - assembled -- black
# scale n  jaguar ss sedan  assembl  black
# oxford diecast
# oxford diecast
# oxford diecast
# ['N Scale', 'n-scale-items', 'oxford-diecast', 'vehicles']
# n scale nscaleitem oxforddiecast vehicl
# fly ignitor battery heated gloves
# fli ignitor batteri heat glove
# fly racing
# fly racing
# fli race
# ['Normal']
# normal
# touring primary & seal kit complete for harley-davidson
# tour primari  seal kit complet for harleydavidson
# cometic
# cometic
# comet
# ['Custom Chrome', 'Harley-Davidson', 'Juntas']
# custom chrome harleydavidson junta
# jobobike lusterka do roweru
# jobobik lusterka do roweru
# jobobike.pl
# jobobike
# jobobik
# ['Akcesoria', 'lusterka do roweru']
# akcesoria lusterka do roweru
# bike trailer with folding frame and quick release wheels
# bike trailer with fold frame and quick releas wheel
# yelpmart llc
# yelpmart llc
# yelpmart llc
# ['Vehicle Parts & Accessories', 'yelpmart llc']
# vehicl part  accessori yelpmart llc
# candylab car donut van
# candylab car donut van
# candylab
# candylab
# candylab
# ['boy', 'candylab', 'candylab cars', 'car', 'car toy', 'child', 'children', 'classic', 'designed in brooklyn', 'designed in nyc', 'donut', 'donuts', 'doughnut', 'doughnuts', 'figurine', 'food truck', 'gifts for children', 'gifts for kids', 'girl', 'heirloom', 'imaginative play', 'kid', 'kids', 'modern', 'natural materials', 'pink', 'responsibly made', 'retro', 'small gifts', 'sustainable', 'toddler', 'toy', 'toys', 'truck', 'van', 'vehicle', 'white', 'wood', 'wooden toys']
# boy candylab candylab car car car toy child children classic design in brooklyn design in nyc donut donut doughnut doughnut figurin food truck gift for children gift for kid girl heirloom imagin play kid kid modern natur materi pink respons made retro small gift sustain toddler toy toy truck van vehicl white wood wooden toy
# th marine anchor master anchor retriever
# th marin anchor master anchor retriev
# th marine
# th marine
# th marin
# ['- buoys', 'th marine']
#  buoy th marin
# candylab junior city scape set
# candylab junior citi scape set
# candylab
# candylab
# candylab
# ['3 Years +', 'candylab', 'Discount Products', 'Discounts', 'Ride On & Vehicles', 'Toddler & Pretend Play', 'Wooden Toys']
#  year  candylab discount product discount ride on  vehicl toddler  pretend play wooden toy
# lower rocker gaskets rubber for harley-davidson
# lower rocker gasket rubber for harleydavidson
# cometic
# cometic
# comet
# ['Custom Chrome', 'Harley-Davidson', 'Juntas']
# custom chrome harleydavidson junta
# oni demon fast mask motorcycle gloves
# oni demon fast mask motorcycl glove
# fast mask
# fast mask
# fast mask
# ['All Gloves', 'Motorcycle Gloves', 'New', 'New Arrivals']
# all glove motorcycl glove new new arriv
# maxxfan insulated exhaust fan cover
# maxxfan insul exhaust fan cover
# overland gear guy
# overland gear guy
# overland gear guy
# ['Maxxfan','Insulated','Exhaust','Fan','Cover']
# maxxfan insul exhaust fan cover
# fly thrust perforated gloves
# fli thrust perfor glove
# fly racing
# fly racing
# fli race
# ['Normal']
# normal
# motorcycle amber/red turn signal light
# motorcycl amber turn signal light
# unbranded
# unbranded
# unbrand
# ['Cheap', 'Condition_New', 'Type_Auto', 'Vendor_Unbranded']
# cheap condit new type auto vendor unbrand
# miata door bushings
# miata door bush
# spiked performance
# spiked performance
# spike perform
# ['miata']
# miata
# toy rc monster spinning car- black
# toy rc monster spin car black
# sharper image
# sharper image
# sharper imag
# ['12-14 Years', '14+ Years', '8-12 Years', 'MDS', 'preschool', 'Preschool_Trains and Vehicles_', 'RC_Buzz', 'rc_cars_trains_', 'Remote Control Cars', 'Remote_control_cars_Cars', 'Remote_control_cars_Electric', 'Vehicles', 'Vehicles_Trains_Cars', 'Vehicles_Trains_Remote control cars']
#  year  year  year md preschool preschool train and vehicl rc buzz rc car train remot control car remot control car car remot control car electr vehicl vehicl train car vehicl train remot control car
# candylab pioneer classic
# candylab pioneer classic
# candylab
# candylab
# candylab
# ['3 Years +', 'candylab', 'Discount Products', 'Discounts', 'Ride On & Vehicles', 'Toddler & Pretend Play', 'Wooden Toys']
#  year  candylab discount product discount ride on  vehicl toddler  pretend play wooden toy
# wood beaded comfort seat cushion comfort massaging car seat cover
# wood bead comfort seat cushion comfort massag car seat cover
# seametal
# seametal
# seamet
# ['Car Auto Office Home 2 Colors', 'Interior Accessories', 'Massage Cushion', 'Seat Cover Massage Cushion', 'Universial Summer Cool seat covers', 'Wooden Bead Seat Cover', 'Wooden Bead Seat Cover Massage']
# car auto offic home  color interior accessori massag cushion seat cover massag cushion universi summer cool seat cover wooden bead seat cover wooden bead seat cover massag
# small bamboo helicopter
# small bamboo helicopt
# kraul
# kraul
# kraul
# ['advent', 'AW18', 'aw18new', 'Brand_Kraul', 'createplay', 'giftsbigkid', 'giftsstocking', 'kraul', 'PNature', 'summer19', 'Type_Toys', 'vehicles']
# advent aw awnew brand kraul createplay giftsbigkid giftsstock kraul pnatur summer type toy vehicl
# flag of canada skull logo vehicle decal
# flag of canada skull logo vehicl decal
# sticker mule
# sticker mule
# sticker mule
# ['Canada', 'International', 'Made in USA', 'Weekend All']
# canada intern made in usa weekend all
# t-h marine hi-jacker fixed jack plate
# th marin hijack fix jack plate
# th marine
# th marine
# th marin
# ['- jack plate', '- TH Marine']
#  jack plate  th marin
# swingarm pivot shaft for harley-davidson
# swingarm pivot shaft for harleydavidson
# paughco
# paughco
# paughco
# ['Custom Chrome', 'Harley-Davidson', 'Motor']
# custom chrome harleydavidson motor
# lubulona wooden car grey with blue figure
# lubulona wooden car grey with blue figur
# lubulona
# lubulona
# lubulona
# ['boy', 'car', 'car toy', 'child', 'children', 'designed in barcelona', 'figurine', 'gifts for children', 'gifts for kids', 'girl', 'grey', 'imaginative play', 'kid', 'kids', 'Lubulona', 'passengers', 'responsibly made', 'toddler', 'toy', 'toys', 'vehicle', 'wood', 'wooden toys']
# boy car car toy child children design in barcelona figurin gift for children gift for kid girl grey imagin play kid kid lubulona passeng respons made toddler toy toy vehicl wood wooden toy
# candylab candycar b.berry
# candylab candycar bberri
# candylab
# candylab
# candylab
# ['3 Years +', 'candylab', 'Discount Products', 'Discounts', 'Ride On & Vehicles', 'Toddler & Pretend Play', 'Wooden Toys']
#  year  candylab discount product discount ride on  vehicl toddler  pretend play wooden toy
# n scale: mi-jack translift® intermodal crane - kit
# n scale mijack translift intermod crane  kit
# walthers cornerstone
# walthers cornerstone
# walther cornerston
# ['TL-Intermodal', 'walthers-cornerstone']
# tlintermod waltherscornerston
# german wwii style half motorcycle helmet with goggles and mask
# german wwii style half motorcycl helmet with goggl and mask
# ahp helmets store
# ahp helmets store
# ahp helmet store
# ['Car accessories', 'german', 'goggles', 'helmet', 'mask', 'motorcycle', 'sports', 'Sports & Lifestyle', 'style', 'ww2', 'wwII']
# car accessori german goggl helmet mask motorcycl sport sport  lifestyl style ww wwii
# salinas rib
# salina rib
# smithfly
# smithfly
# smithfli
# ['Rigid Inflatable']
# rigid inflat
# severe duty intake valve for harley-davidson
# sever duti intak valv for harleydavidson
# manley
# manley
# manley
# ['Custom Chrome', 'Harley-Davidson', 'Motor']
# custom chrome harleydavidson motor
# pizza and hamburger food trailers -- kit -  scale: ho
# pizza and hamburg food trailer  kit   scale ho
# walthers scenemaster
# walthers scenemaster
# walther scenemast
# ['Dealer Special', 'HO Scale', 'ho-scale-items', 'vehicles', 'walthers-scenemaster']
# dealer special ho scale hoscaleitem vehicl walthersscenemast
# spacer, pinion gear shaft for harley-davidson
# spacer pinion gear shaft for harleydavidson
# cce
# cce
# cce
# ['Custom Chrome', 'Harley-Davidson', 'Motor']
# custom chrome harleydavidson motor
# n scale: volkswagen pickup - light gray
# n scale volkswagen pickup  light gray
# oxford diecast
# oxford diecast
# oxford diecast
# ['n-scale-products', 'oxford-diecast', 'TL-Vehicles', 'vehicles']
# nscaleproduct oxforddiecast tlvehicl vehicl
# multi-function glasses holder for car sun visor pu leather card clip
# multifunct glass holder for car sun visor pu leather card clip
# seametal
# seametal
# seamet
# ['Car Glasses Holder', 'Car Visor Sunglasses Holder Clip', 'Interior Accessories', 'Leather Car Sunglasses Holder', 'Multifunctional Car Sunglasses Holder', 'Sun Visor Glasses Holder']
# car glass holder car visor sunglass holder clip interior accessori leather car sunglass holder multifunct car sunglass holder sun visor glass holder
# mystery motorcycle  gloves
# mysteri motorcycl  glove
# fast mask
# fast mask
# fast mask
# ['Mystery','Motorcycle','','Gloves']
# mysteri motorcycl glove
# kid o mini jet
# kid o mini jet
# kid o
# kid o
# kid o
# ['myland', 'spo-disabled']
# myland spodis
# limitless car seat cover
# limitless car seat cover
# icedeagle
# icedeagle
# icedeagl
# ['Limitless','Car','Seat','Cover']
# limitless car seat cover
# bajo double decker bus
# bajo doubl decker bu
# bajo
# bajo
# bajo
# ['18 Months +', 'Bajo', 'Ride On & Vehicles', 'Warehouse', 'Warehouse Sale', 'Wooden Toys']
#  month  bajo ride on  vehicl warehous warehous sale wooden toy
# race tracks for boys car adventure toys
# race track for boy car adventur toy
# ealingkids
# ealingkids
# ealingkid
# ['2 to 4 Year Olds', '3-6 Years', '4 to 6 Year Olds', 'Blocks Play', 'Cars & Trucks', 'City & Construction', 'DIY & Physical Activity', 'For Boys', 'For Girls', 'Gifts for Boys', 'Gifts for Girls', 'Kids Gifts for the Builder', 'Magnetic Tiles', 'Summer deals', 'Table Games', 'Toys', 'yaoyanxia']
#  to  year old  year  to  year old block play car  truck citi  construct diy  physic activ for boy for girl gift for boy gift for girl kid gift for the builder magnet tile summer deal tabl game toy yaoyanxia
# candylab car patty's hamburger van
# candylab car patti hamburg van
# candylab
# candylab
# candylab
# ['boy', 'burger', 'candylab', 'candylab cars', 'car', 'car toy', 'child', 'children', 'classic', 'designed in brooklyn', 'designed in nyc', 'figurine', 'food truck', 'gifts for children', 'gifts for kids', 'girl', 'green', 'hamburger', 'heirloom', 'imaginative play', 'kid', 'kids', 'modern', 'natural materials', 'orange', 'responsibly made', 'retro', 'small gifts', 'sustainable', 'toddler', 'toy', 'toys', 'truck', 'van', 'vehicle', 'wood', 'wooden toys', 'yellow']
# boy burger candylab candylab car car car toy child children classic design in brooklyn design in nyc figurin food truck gift for children gift for kid girl green hamburg heirloom imagin play kid kid modern natur materi orang respons made retro small gift sustain toddler toy toy truck van vehicl wood wooden toy yellow
# nypd playset
# nypd playset
# daron worldwide trading, inc.
# daron worldwide trading
# daron worldwid trade
# ['3-4 Years', '5-7 Years', '8-12 Years', 'new york city', 'Playsets-Racetracks_NYC themed cars', 'Preschool_Play Sets', 'Preschool_Trains and Vehicles_', 'trains_vehicles', 'vehicles', 'Vehicles_Trains_NYC themed cars']
#  year  year  year new york citi playsetsracetrack nyc theme car preschool play set preschool train and vehicl train vehicl vehicl vehicl train nyc theme car
# fashion off road helmet
# fashion off road helmet
# ahp helmets store
# ahp helmets store
# ahp helmet store
# ['helmet', 'Helmets', 'Motorcycle', 'motorcycle helmets', 'Off Road']
# helmet helmet motorcycl motorcycl helmet off road
# car sound control led lights voice-activated music rhythm ambient light
# car sound control led light voiceactiv music rhythm ambient light
# seametal
# seametal
# seamet
# ['32 LED 18 Colors Car Decorative Lamp', 'Car Ambient Light', 'Car Home Rhythm Decorative Lamp', 'Car RGB LED Interior Light', 'Car Sound Control LED Lights', 'Voice-Activated Music Rhythm Ambient Light']
#  led  color car decor lamp car ambient light car home rhythm decor lamp car rgb led interior light car sound control led light voiceactiv music rhythm ambient light
# bison command vehicle - resin kit -  scale: ho
# bison command vehicl  resin kit   scale ho
# trident miniatures
# trident miniatures
# trident miniatur
# ['Dealer Special', 'HO Scale', 'ho-scale-items', 'trident-miniatures', 'vehicles']
# dealer special ho scale hoscaleitem tridentminiatur vehicl
# candylab moo milk van
# candylab moo milk van
# candylab
# candylab
# candylab
# ['3 Years +', 'candylab', 'Discount Products', 'Discounts', 'Ride On & Vehicles', 'Toddler & Pretend Play', 'Wooden Toys']
#  year  candylab discount product discount ride on  vehicl toddler  pretend play wooden toy
# truck - modern era vehicles -- red, white -  scale: ho
# truck  modern era vehicl  red white   scale ho
# woodland scenics
# woodland scenics
# woodland scenic
# ['HO Scale', 'ho-scale-items', 'vehicles', 'woodland-scenics']
# ho scale hoscaleitem vehicl woodlandscen
# car sticker flags decal american flag sticker for
# car sticker flag decal american flag sticker for
# cyan selene
# cyan selene
# cyan selen
# ['Other']
# other
# lazer helmets bayamo pit bull - full face
# lazer helmet bayamo pit bull  full face
# open box bargains
# open box bargains
# open box bargain
# ['65061090', 'Antiscratch Pinlock Ready Visor', 'Bayamo', 'ECE', 'Full face', 'Helmet', 'Lazer', 'open box bargains', 'Pit Bull', 'Tax Rate 18%', 'White+Black+Red', 'XL', 'XXL']
#  antiscratch pinlock readi visor bayamo ece full face helmet lazer open box bargain pit bull tax rate  whiteblackr xl xxl
# deutz agrotron tractor
# deutz agrotron tractor
# siku
# siku
# siku
# ['$0 to $25', 'diecast-models', 'gift-finder', 'gift-wrap', 'junior-schoolers', 'planes', 'preschoolers', 'shopall', 'siku', 'stocking-fillers', 'unisex', 'vehicles']
#  to  diecastmodel giftfind giftwrap juniorschool plane preschool shopal siku stockingfil unisex vehicl

# %%
print(all_data.head())
# Out:
#                                            title      vendor  \
# 0  fidel super premium adult larg breed dog food       fidel
# 1                   foldabl pet toy linen storag   cap point
# 2                                 bok dok diaper    pet home
# 3                           tastybon toy chicken    tastybon
# 4             leather leash tab  short dog leash  mighti paw
#
#                                                 tags category
# 0  adult bangalor chennai chicken doberman dog dr...        0
# 1                       foldabl pet toy linen storag        0
# 2  brand pet arabia categori pet home categori sm...        0
# 3                               tastybon toy chicken        0
# 4                              leash leash tab train        0

# %% [markdown]
# # Featurizing data

# %% [markdown]
# Now we should convert all we have from texts to numbers and features.
# Some ways exists but on my experience i Choose Word2vec.
# The ways :
# - Bag of Words
# - Word2Vec
# - Bert
# ...
#
# There are some pretrained models which are trained on large datasets.
# some of them are :
# - Google model
# - Glove-twiiter
# ...
#
# I first chose glove-twitter-25 with 25 neurons in embedding. but the results got better when i chose the bigger model glove-twitter-50. I also used google-word2vec-300 model, but this was a huge model and was very time-consuming model for extracting feature.

# %%
import gensim.downloader
w2v_model = gensim.downloader.load('glove-twitter-50')
# w2v_model = gensim.downloader.load('word2vec-google-news-300')

# %% [markdown]
# You can check the pretrained model with any word exist in its dataset.

# %%
w2v_model.most_similar('cat')
# Out:
# [('dog', 0.9429584741592407),
#  ('pet', 0.8726722002029419),
#  ('kitty', 0.8676421046257019),
#  ('bear', 0.8655619025230408),
#  ('monkey', 0.8506731390953064),
#  ('pig', 0.8369912505149841),
#  ('puppy', 0.8335511684417725),
#  ('kitten', 0.829558789730072),
#  ('cats', 0.8218452334403992),
#  ('dogs', 0.8203402161598206)]

# %%
w2v_model["dog"].shape
# Out:
# (300,)

# %% [markdown]
# This a function which gets a cleaned sentence with just space betwenn words.
#
#
# in This function I put every splitted word into word2vec model and get embedding. After that i average the embeddings over a sentence. I mean averaging embedding show of each word in a sentence given.

# %% [markdown]
# First of all  i checked whether the performance improves by not averaging and just adding or not and the result was : Yes! by averaging word embeddings, final results get better.

# %%
def featurize_sentence(sentence , embedding_size=25):
    words =sentence.split(" ")
    
    embeddings = np.zeros((embedding_size))
    
    
    for word in words:
        if word in w2v_model.index_to_key:
            
            embeddings +=w2v_model[word]
     
           
    
    return embeddings

# %% [markdown]
# In This section I am going to featurize each text column as a sentence. so we have three averaged word embeddings of each colum. After that it can be a choice between concatinating features or averaging all.
#
# I tried both of them and the results were better when concatinating.

# %%
embedding_size = 50
all_features = np.zeros((all_data.shape[0], 3*embedding_size))
all_labels = np.zeros((all_data.shape[0],))

for index, row in all_data.iterrows():
    title_embedding = featurize_sentence(row["title"],embedding_size)
    # print("title_embedding_shape : " ,title_embedding.shape)
    
    vendor_embedding = featurize_sentence(row["vendor"],embedding_size)
    # print("vendor_embedding_shape : " ,vendor_embedding.shape)
    
    tags_embedding = featurize_sentence(row["tags"],embedding_size)
    # print("tags_embedding_shape : " ,tags_embedding.shape)
    
    
    all_features[index] = np.transpose(np.hstack([title_embedding,vendor_embedding,tags_embedding]))
    # all_features[index] = title_embedding + vendor_embedding + tags_embedding
    
    
    all_labels[index] = row["category"]
    

print(all_features.shape)
print(all_labels.shape)
# Out:
# (5270, 150)
# (5270,)

# %% [markdown]
# # Train/Test Splitting

# %% [markdown]
# 20% of data for testing

# %%
X_train, X_test, y_train, y_test = train_test_split(all_features,all_labels, test_size=0.20, random_state=42)

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
type(X_train)
# Out:
# (4216, 150)
# (4216,)
# (1054, 150)
# (1054,)
# numpy.ndarray

# %% [markdown]
# # Model selection / Training / Evaluation

# %% [markdown]
# ## Random Forest classifier

# %% [markdown]
# ### trainig with n_estimators=100

# %%
from sklearn.ensemble import RandomForestClassifier 
clf = RandomForestClassifier(n_estimators=100,class_weight = 'balanced', max_features = 'auto')
clf_model = clf.fit(X_train, y_train)

# %% [markdown]
# ### Evaluation and Metrics with n_estimators=100

# %%
# Use the trained model to make predictions on the test data
y_pred = clf_model.predict(X_test)

# %%
precision = round(precision_score(y_test, y_pred,average='weighted'),3)
recall = round(recall_score(y_test, y_pred,average='weighted'),3)
accuracy = round(accuracy_score(y_test, y_pred), 3)

print('Precision: {} / Recall: {} / Accuracy: {}'.format(precision, recall, accuracy))
from sklearn.metrics import classification_report, confusion_matrix


# print(confusion_matrix(y_test,y_pred))X_test
print(classification_report(y_test,y_pred))
# Out:
# Precision: 0.672 / Recall: 0.58 / Accuracy: 0.58
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.78      0.75       109
#          1.0       0.41      0.93      0.57       207
#          2.0       0.92      0.29      0.44        42
#          3.0       0.89      0.34      0.49        50
#          4.0       1.00      0.31      0.48        16
#          5.0       1.00      0.33      0.50         9
#          6.0       0.57      0.19      0.29        21
#          7.0       0.73      0.80      0.76        79
#          8.0       1.00      0.31      0.47        42
#          9.0       0.00      0.00      0.00         7
#         10.0       0.56      0.43      0.49        67
#         11.0       0.55      0.34      0.42        64
#         12.0       0.76      0.59      0.66        82
#         13.0       0.74      0.88      0.81        66
#         14.0       1.00      0.04      0.08        23
#         15.0       1.00      1.00      1.00         1
#         16.0       1.00      0.30      0.46        10
#         17.0       0.51      0.28      0.36        78
#         18.0       0.75      0.42      0.54        64
#         19.0       1.00      0.29      0.45        17
#
#     accuracy                           0.58      1054
#    macro avg       0.76      0.44      0.50      1054
# weighted avg       0.67      0.58      0.56      1054
# /home/mostafa/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/mostafa/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/mostafa/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/mostafa/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### trainig with n_estimators=1000

# %%
from sklearn.ensemble import RandomForestClassifier 
clf = RandomForestClassifier(n_estimators=1000,class_weight = 'balanced', max_features = 'auto')
clf_model = clf.fit(X_train, y_train)

# %% [markdown]
# ### Evaluation and Metrics with n_estimators=100

# %%
# Use the trained model to make predictions on the test data
y_pred = clf_model.predict(X_test)

# %%
precision = round(precision_score(y_test, y_pred,average='weighted'),3)
recall = round(recall_score(y_test, y_pred,average='weighted'),3)
accuracy = round(accuracy_score(y_test, y_pred), 3)

print('Precision: {} / Recall: {} / Accuracy: {}'.format(precision, recall, accuracy))
from sklearn.metrics import classification_report, confusion_matrix


# print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# Precision: 0.732 / Recall: 0.612 / Accuracy: 0.612
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.82      0.81       109
#          1.0       0.40      0.96      0.57       207
#          2.0       1.00      0.33      0.50        42
#          3.0       0.95      0.40      0.56        50
#          4.0       1.00      0.31      0.48        16
#          5.0       1.00      0.33      0.50         9
#          6.0       0.83      0.24      0.37        21
#          7.0       0.78      0.85      0.81        79
#          8.0       1.00      0.38      0.55        42
#          9.0       0.00      0.00      0.00         7
#         10.0       0.74      0.52      0.61        67
#         11.0       0.68      0.33      0.44        64
#         12.0       0.84      0.56      0.67        82
#         13.0       0.81      0.89      0.85        66
#         14.0       1.00      0.04      0.08        23
#         15.0       1.00      1.00      1.00         1
#         16.0       1.00      0.30      0.46        10
#         17.0       0.61      0.32      0.42        78
#         18.0       0.82      0.48      0.61        64
#         19.0       1.00      0.29      0.45        17
#
#     accuracy                           0.61      1054
#    macro avg       0.81      0.47      0.54      1054
# weighted avg       0.73      0.61      0.60      1054
# /home/mostafa/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/mostafa/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/mostafa/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/mostafa/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ## KNN

# %% [markdown]
# ### training

# %%
from sklearn.neighbors import KNeighborsClassifier
clf = KNeighborsClassifier(n_neighbors=15)
clf_model = clf.fit(X_train, y_train)

# %% [markdown]
# ### Evaluation and Metrics

# %%
# Use the trained model to make predictions on the test data
y_pred = clf_model.predict(X_test)

# %%
precision = round(precision_score(y_test, y_pred,average='weighted'),3)
recall = round(recall_score(y_test, y_pred,average='weighted'),3)
accuracy = round(accuracy_score(y_test, y_pred), 3)

print('Precision: {} / Recall: {} / Accuracy: {}'.format(precision, recall, accuracy))
from sklearn.metrics import classification_report, confusion_matrix


# print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# Precision: 0.515 / Recall: 0.488 / Accuracy: 0.488
#               precision    recall  f1-score   support
#
#          0.0       0.45      0.81      0.58       109
#          1.0       0.47      0.78      0.59       207
#          2.0       0.59      0.24      0.34        42
#          3.0       0.46      0.38      0.42        50
#          4.0       1.00      0.25      0.40        16
#          5.0       0.18      0.22      0.20         9
#          6.0       0.62      0.24      0.34        21
#          7.0       0.61      0.46      0.52        79
#          8.0       0.42      0.19      0.26        42
#          9.0       0.00      0.00      0.00         7
#         10.0       0.54      0.40      0.46        67
#         11.0       0.29      0.22      0.25        64
#         12.0       0.44      0.52      0.48        82
#         13.0       0.67      0.70      0.68        66
#         14.0       1.00      0.04      0.08        23
#         15.0       0.00      0.00      0.00         1
#         16.0       1.00      0.30      0.46        10
#         17.0       0.53      0.26      0.34        78
#         18.0       0.56      0.38      0.45        64
#         19.0       0.40      0.12      0.18        17
#
#     accuracy                           0.49      1054
#    macro avg       0.51      0.33      0.35      1054
# weighted avg       0.51      0.49      0.46      1054
# /home/mostafa/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/mostafa/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/mostafa/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/mostafa/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ## Logistic regression

# %% [markdown]
# ### training

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression(C=10,penalty='l2', solver='newton-cg')
clf_model = clf.fit(X_train, y_train)
# Out:
# /home/mostafa/anaconda3/lib/python3.8/site-packages/sklearn/utils/optimize.py:210: ConvergenceWarning: newton-cg failed to converge. Increase the number of iterations.
#   warnings.warn(

# %% [markdown]
# ### metrics and evaluation

# %%
# Use the trained model to make predictions on the test data
y_pred = clf_model.predict(X_test)

# %%
precision = round(precision_score(y_test, y_pred,average='weighted'),3)
recall = round(recall_score(y_test, y_pred,average='weighted'),3)
accuracy = round(accuracy_score(y_test, y_pred), 3)

print('Precision: {} / Recall: {} / Accuracy: {}'.format(precision, recall, accuracy))
from sklearn.metrics import classification_report, confusion_matrix


# print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# Precision: 0.596 / Recall: 0.586 / Accuracy: 0.586
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.73      0.75       109
#          1.0       0.71      0.69      0.70       207
#          2.0       0.53      0.48      0.50        42
#          3.0       0.56      0.58      0.57        50
#          4.0       0.24      0.31      0.27        16
#          5.0       0.25      0.44      0.32         9
#          6.0       0.36      0.48      0.41        21
#          7.0       0.65      0.67      0.66        79
#          8.0       0.69      0.52      0.59        42
#          9.0       0.06      0.14      0.08         7
#         10.0       0.60      0.54      0.57        67
#         11.0       0.40      0.41      0.40        64
#         12.0       0.73      0.74      0.74        82
#         13.0       0.71      0.80      0.75        66
#         14.0       0.31      0.22      0.26        23
#         15.0       0.33      1.00      0.50         1
#         16.0       0.21      0.30      0.25        10
#         17.0       0.45      0.37      0.41        78
#         18.0       0.53      0.55      0.54        64
#         19.0       0.20      0.18      0.19        17
#
#     accuracy                           0.59      1054
#    macro avg       0.46      0.51      0.47      1054
# weighted avg       0.60      0.59      0.59      1054

# %% [markdown]
# ## Decision tree

# %% [markdown]
# #### training

# %%
from sklearn import tree
# choose from different tunable hyper parameters
clf = tree.DecisionTreeClassifier(max_depth=20,criterion='gini')
clf_model = clf.fit(X_train, y_train)

# %% [markdown]
# ### metrics and evaluation

# %%
# Use the trained model to make predictions on the test data
y_pred = clf_model.predict(X_test)

# %%
precision = round(precision_score(y_test, y_pred,average='weighted'),3)
recall = round(recall_score(y_test, y_pred,average='weighted'),3)
accuracy = round(accuracy_score(y_test, y_pred), 3)

print('Precision: {} / Recall: {} / Accuracy: {}'.format(precision, recall, accuracy))
from sklearn.metrics import classification_report, confusion_matrix


# print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# Precision: 0.337 / Recall: 0.331 / Accuracy: 0.331
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.52      0.52       109
#          1.0       0.46      0.43      0.45       207
#          2.0       0.28      0.26      0.27        42
#          3.0       0.26      0.22      0.24        50
#          4.0       0.23      0.31      0.26        16
#          5.0       0.00      0.00      0.00         9
#          6.0       0.17      0.19      0.18        21
#          7.0       0.36      0.38      0.37        79
#          8.0       0.24      0.19      0.21        42
#          9.0       0.00      0.00      0.00         7
#         10.0       0.26      0.36      0.30        67
#         11.0       0.17      0.16      0.16        64
#         12.0       0.37      0.37      0.37        82
#         13.0       0.50      0.41      0.45        66
#         14.0       0.00      0.00      0.00        23
#         15.0       0.25      1.00      0.40         1
#         16.0       0.19      0.30      0.23        10
#         17.0       0.21      0.24      0.23        78
#         18.0       0.30      0.22      0.25        64
#         19.0       0.18      0.29      0.22        17
#
#     accuracy                           0.33      1054
#    macro avg       0.25      0.29      0.26      1054
# weighted avg       0.34      0.33      0.33      1054
# /home/mostafa/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/mostafa/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/mostafa/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/mostafa/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ## Adaboost

# %% [markdown]
# ### training

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
 
# Choosing Decision Tree with 1 level as the weak learner
DTC=DecisionTreeClassifier(max_depth=2)
clf = AdaBoostClassifier(n_estimators=20, base_estimator=DTC ,learning_rate=0.01)
clf_model = clf.fit(X_train, y_train)

# %% [markdown]
# ### metrics and ecaluation

# %%
# Use the trained model to make predictions on the test data
y_pred = clf_model.predict(X_test)

# %%
precision = round(precision_score(y_test, y_pred,average='weighted'),3)
recall = round(recall_score(y_test, y_pred,average='weighted'),3)
accuracy = round(accuracy_score(y_test, y_pred), 3)

print('Precision: {} / Recall: {} / Accuracy: {}'.format(precision, recall, accuracy))
from sklearn.metrics import classification_report, confusion_matrix


# print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# Precision: 0.266 / Recall: 0.302 / Accuracy: 0.302
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.51      0.56       109
#          1.0       0.24      0.99      0.38       207
#          2.0       0.00      0.00      0.00        42
#          3.0       0.00      0.00      0.00        50
#          4.0       0.00      0.00      0.00        16
#          5.0       0.00      0.00      0.00         9
#          6.0       0.00      0.00      0.00        21
#          7.0       0.45      0.35      0.40        79
#          8.0       0.00      0.00      0.00        42
#          9.0       0.00      0.00      0.00         7
#         10.0       0.50      0.01      0.03        67
#         11.0       0.67      0.03      0.06        64
#         12.0       0.00      0.00      0.00        82
#         13.0       0.79      0.41      0.54        66
#         14.0       0.00      0.00      0.00        23
#         15.0       0.00      0.00      0.00         1
#         16.0       0.00      0.00      0.00        10
#         17.0       0.00      0.00      0.00        78
#         18.0       0.00      0.00      0.00        64
#         19.0       0.00      0.00      0.00        17
#
#     accuracy                           0.30      1054
#    macro avg       0.16      0.12      0.10      1054
# weighted avg       0.27      0.30      0.20      1054
# /home/mostafa/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/mostafa/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/mostafa/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/mostafa/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ## Linear SVM

# %% [markdown]
# ### training

# %%
from sklearn.svm import LinearSVC
clf = LinearSVC()
clf_model = clf.fit(X_train, y_train)
# Out:
# /home/mostafa/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(

# %% [markdown]
# ### metrics and evaluation

# %%
# Use the trained model to make predictions on the test data
y_pred = clf_model.predict(X_test)

# %%
precision = round(precision_score(y_test, y_pred,average='weighted'),3)
recall = round(recall_score(y_test, y_pred,average='weighted'),3)
accuracy = round(accuracy_score(y_test, y_pred), 3)

print('Precision: {} / Recall: {} / Accuracy: {}'.format(precision, recall, accuracy))
from sklearn.metrics import classification_report, confusion_matrix


# print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# Precision: 0.576 / Recall: 0.565 / Accuracy: 0.565
#               precision    recall  f1-score   support
#
#          0.0       0.74      0.72      0.73       109
#          1.0       0.68      0.64      0.66       207
#          2.0       0.52      0.36      0.42        42
#          3.0       0.60      0.52      0.56        50
#          4.0       0.27      0.19      0.22        16
#          5.0       0.23      0.33      0.27         9
#          6.0       0.50      0.43      0.46        21
#          7.0       0.50      0.80      0.61        79
#          8.0       0.38      0.62      0.47        42
#          9.0       0.17      0.14      0.15         7
#         10.0       0.65      0.55      0.60        67
#         11.0       0.43      0.28      0.34        64
#         12.0       0.54      0.82      0.65        82
#         13.0       0.75      0.77      0.76        66
#         14.0       0.67      0.17      0.28        23
#         15.0       0.33      1.00      0.50         1
#         16.0       0.14      0.30      0.19        10
#         17.0       0.61      0.29      0.40        78
#         18.0       0.46      0.52      0.49        64
#         19.0       0.12      0.06      0.08        17
#
#     accuracy                           0.56      1054
#    macro avg       0.46      0.48      0.44      1054
# weighted avg       0.58      0.56      0.55      1054

# %% [markdown]
# ## Shallow DNN

# %% [markdown]
# ### Data preparation

# %%
from sklearn.preprocessing import OneHotEncoder
onehot_encoder = OneHotEncoder(sparse=False)
all_labels = all_labels.reshape(len(all_labels), 1)
all_labels_onehot_encoded = np.array(onehot_encoder.fit_transform(all_labels))

# %%
X_train, X_test, y_train, y_test = train_test_split(all_features,all_labels_onehot_encoded, test_size=0.20, random_state=42)

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
type(X_train)
# Out:
# (4216, 150)
# (4216, 20)
# (1054, 150)
# (1054, 20)
# numpy.ndarray

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train,y_train, test_size=0.10, random_state=32)

print(X_train.shape)
print(y_train.shape)
print(X_val.shape)
print(y_val.shape)
type(X_train)
# Out:
# (3794, 150)
# (3794, 20)
# (422, 150)
# (422, 20)
# numpy.ndarray

# %% [markdown]
# ### training

# %%
clf=Sequential()

clf.add(Dense(512, activation='softmax'))
clf.add(Dropout(0.5))
clf.add(Dense(50, activation='softmax'))
clf.add(Dropout(0.5))
clf.add(Dense(20, activation='softmax'))
# compile the clf
optimzer = Adam(learning_rate=0.01, clipvalue=0.5) # clip value to avoid the gradient exploding

clf.compile(optimizer=optimzer, 
              loss='categorical_crossentropy', 
              metrics=['acc'])

# fit the clf
history = clf.fit(X_train, y_train, 
                    batch_size=2048, 
                    epochs=2000,  
                    verbose=2,
                    validation_data=(X_val,y_val))
# Out:
# Epoch 1/2000
# 2/2 - 0s - loss: 2.9880 - acc: 0.0854 - val_loss: 2.9670 - val_acc: 0.1919
# Epoch 2/2000
# 2/2 - 0s - loss: 2.9615 - acc: 0.1518 - val_loss: 2.9432 - val_acc: 0.1919
# Epoch 3/2000
# 2/2 - 0s - loss: 2.9373 - acc: 0.1587 - val_loss: 2.9211 - val_acc: 0.1919
# Epoch 4/2000
# 2/2 - 0s - loss: 2.9147 - acc: 0.1663 - val_loss: 2.9004 - val_acc: 0.1919
# Epoch 5/2000
# 2/2 - 0s - loss: 2.8929 - acc: 0.1761 - val_loss: 2.8812 - val_acc: 0.1919
# Epoch 6/2000
2000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-51-cd45bc0dabd2> in <module>
#      14
#      15 # fit the clf
# ---> 16 history = clf.fit(X_train, y_train,
#      17                     batch_size=2048,
#      18                     epochs=2000,
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1121                 model=self,
#    1122                 steps_per_execution=self._steps_per_execution)
# -> 1123           val_logs = self.evaluate(
#    1124               x=val_x,
#    1125               y=val_y,
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict)
#    1371       self._test_counter.assign(0)
#    1372       callbacks.on_test_begin()
# -> 1373       for _, iterator in data_handler.enumerate_epochs():  # Single epoch.
#    1374         self.reset_metrics()
#    1375         with data_handler.catch_stop_iteration():
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/data_adapter.py in enumerate_epochs(self)
#    1136     """Yields `(epoch, tf.data.Iterator)`."""
#    1137     with self._truncate_execution_to_epoch():
# -> 1138       data_iterator = iter(self._dataset)
#    1139       for epoch in range(self._initial_epoch, self._epochs):
#    1140         if self._insufficient_data:  # Set by `catch_stop_iteration`.
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/data/ops/dataset_ops.py in __iter__(self)
#     413     """
#     414     if context.executing_eagerly() or ops.inside_function():
# --> 415       return iterator_ops.OwnedIterator(self)
#     416     else:
#     417       raise RuntimeError("__iter__() is only supported inside of tf.function "
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/data/ops/iterator_ops.py in __init__(self, dataset, components, element_spec, job_token)
#     694           context.context().device_spec.device_type != "CPU"):
#     695         with ops.device("/cpu:0"):
# --> 696           self._create_iterator(dataset)
#     697       else:
#     698         self._create_iterator(dataset)
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/data/ops/iterator_ops.py in _create_iterator(self, dataset)
#     720               output_shapes=self._flat_output_shapes))
#     721       if self._job_token is None:
# --> 722         gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#     723       else:
#     724         gen_experimental_dataset_ops.make_data_service_iterator(
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/ops/gen_dataset_ops.py in make_iterator(dataset, iterator, name)
#    3003   if tld.is_eager:
#    3004     try:
# -> 3005       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3006         _ctx._context_handle, tld.device_name, "MakeIterator", name,
#    3007         tld.op_callbacks, dataset, iterator)
#
# KeyboardInterrupt:

# %% [markdown]
# ### metrics and evaluation

# %%
y_test = np.argmax(y_test, axis =1 )
# Use the trained model to make predictions on the test data
y_pred = clf_model.predict(X_test)

# %%
precision = round(precision_score(y_test, y_pred,average='weighted'),3)
recall = round(recall_score(y_test, y_pred,average='weighted'),3)
accuracy = round(accuracy_score(y_test, y_pred), 3)

print('Precision: {} / Recall: {} / Accuracy: {}'.format(precision, recall, accuracy))
from sklearn.metrics import classification_report, confusion_matrix


# print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# Precision: 0.576 / Recall: 0.565 / Accuracy: 0.565
#               precision    recall  f1-score   support
#
#            0       0.74      0.72      0.73       109
#            1       0.68      0.64      0.66       207
#            2       0.52      0.36      0.42        42
#            3       0.60      0.52      0.56        50
#            4       0.27      0.19      0.22        16
#            5       0.23      0.33      0.27         9
#            6       0.50      0.43      0.46        21
#            7       0.50      0.80      0.61        79
#            8       0.38      0.62      0.47        42
#            9       0.17      0.14      0.15         7
#           10       0.65      0.55      0.60        67
#           11       0.43      0.28      0.34        64
#           12       0.54      0.82      0.65        82
#           13       0.75      0.77      0.76        66
#           14       0.67      0.17      0.28        23
#           15       0.33      1.00      0.50         1
#           16       0.14      0.30      0.19        10
#           17       0.61      0.29      0.40        78
#           18       0.46      0.52      0.49        64
#           19       0.12      0.06      0.08        17
#
#     accuracy                           0.56      1054
#    macro avg       0.46      0.48      0.44      1054
# weighted avg       0.58      0.56      0.55      1054

# %% [markdown]
# ## Deep NN

# %% [markdown]
# ### Data preparation

# %%
from sklearn.preprocessing import OneHotEncoder
onehot_encoder = OneHotEncoder(sparse=False)
all_labels = all_labels.reshape(len(all_labels), 1)
all_labels_onehot_encoded = np.array(onehot_encoder.fit_transform(all_labels))
X_train, X_test, y_train, y_test = train_test_split(all_features,all_labels_onehot_encoded, test_size=0.20, random_state=42)

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
type(X_train)
# Out:
# (4216, 150)
# (4216, 20)
# (1054, 150)
# (1054, 20)
# numpy.ndarray

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train,y_train, test_size=0.10, random_state=32)

print(X_train.shape)
print(y_train.shape)
print(X_val.shape)
print(y_val.shape)
type(X_train)
# Out:
# (3794, 150)
# (3794, 20)
# (422, 150)
# (422, 20)
# numpy.ndarray

# %% [markdown]
# ### training

# %%
clf=Sequential()

clf.add(Conv1D(128, kernel_size = 5, activation='softmax'))
clf.add(Dropout(0.5))
clf.add(Dense(50, activation='softmax'))
clf.add(Dropout(0.5))
clf.add(Dense(20, activation='softmax'))
# compile the clf
optimzer = Adam(learning_rate=0.01, clipvalue=0.5) # clip value to avoid the gradient exploding

clf.compile(optimizer=optimzer, 
              loss='categorical_crossentropy', 
              metrics=['acc'])

# fit the clf
history = clf.fit(X_train, y_train, 
                    batch_size=2048, 
                    epochs=2000,  
                    verbose=2,
                    validation_data=(X_val,y_val))

# %% [markdown]
# ### metrics and evaluation

# %%
y_test = np.argmax(y_test, axis =1 )
# Use the trained model to make predictions on the test data
y_pred = clf_model.predict(X_test)

precision = round(precision_score(y_test, y_pred,average='weighted'),3)
recall = round(recall_score(y_test, y_pred,average='weighted'),3)
accuracy = round(accuracy_score(y_test, y_pred), 3)

print('Precision: {} / Recall: {} / Accuracy: {}'.format(precision, recall, accuracy))
from sklearn.metrics import classification_report, confusion_matrix


# print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))

# %% [markdown]
# ## NEW

# %%
X_train, X_test, y_train, y_test = train_test_split(all_data["title"],all_labels, test_size=0.20, random_state=42)

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
type(X_train)
# Out:
# (4216,)
# (4216, 1)
# (1054,)
# (1054, 1)
# pandas.core.series.Series

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfTransformer

clf_model = Pipeline([('vect', CountVectorizer()),
               ('tfidf', TfidfTransformer()),
               ('clf', MultinomialNB()),
              ])
clf_model.fit(X_train,y_train)
# Out:
# /home/mostafa/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Pipeline(steps=[('vect', CountVectorizer()), ('tfidf', TfidfTransformer()),
#                 ('clf', MultinomialNB())])

# %%
# Use the trained model to make predictions on the test data
y_pred = clf_model.predict(X_test)

precision = round(precision_score(y_test, y_pred,average='weighted'),3)
recall = round(recall_score(y_test, y_pred,average='weighted'),3)
accuracy = round(accuracy_score(y_test, y_pred), 3)

print('Precision: {} / Recall: {} / Accuracy: {}'.format(precision, recall, accuracy))
from sklearn.metrics import classification_report, confusion_matrix


# print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))

# %% [markdown]
# ## Doc2Vec (not completed)

# %%
from gensim.models import Doc2Vec
from gensim.models.doc2vec import TaggedDocument

# %%
X_train, X_test, y_train, y_test = train_test_split(all_data["title"],all_labels, test_size=0.20, random_state=42)

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
type(X_train)

# %%
def label_sentences(corpus, label_type):
    """
    Gensim's Doc2Vec implementation requires each document/paragraph to have a label associated with it.
    We do this by using the TaggedDocument method. The format will be "TRAIN_i" or "TEST_i" where "i" is
    a dummy index of the post.
    """
    labeled = []
    for i, v in enumerate(corpus):
        label = label_type + '_' + str(i)
        labeled.append(doc2vec.TaggedDocument(v.split(), [label]))
    return labeled

# %%
embedding_size = 50
all_features = np.zeros((all_data.shape[0], 3*embedding_size))
all_labels = np.zeros((all_data.shape[0],))

for index, row in all_data.iterrows():
    label_sentences()
    title_embedding = featurize_sentence(row["title"],embedding_size)
    # print("title_embedding_shape : " ,title_embedding.shape)
    
    vendor_embedding = featurize_sentence(row["vendor"],embedding_size)
    # print("vendor_embedding_shape : " ,vendor_embedding.shape)
    
    tags_embedding = featurize_sentence(row["tags"],embedding_size)
    # print("tags_embedding_shape : " ,tags_embedding.shape)
    
    
    all_features[index] = np.transpose(np.hstack([title_embedding,vendor_embedding,tags_embedding]))
    # all_features[index] = title_embedding + vendor_embedding + tags_embedding
    
    
    all_labels[index] = row["category"]
    

print(all_features.shape)
print(all_labels.shape)

# %% [markdown]
# # Result and Conclusion

# %% [markdown]
# All of Models are evaluated in terms of Precision, Accuracy, Recall , F1-score.
#
# The random Forest model is the best model trained on this data. the shallow DNN is also good when is not overfitting.  So we choose Random Forest Model for this.
#
# Because the size of dataset is relatively small or medium, this is better to not use deep learning because it is an over design. but the best model (RFM) has accuracy near 0.73 which is not high => so we can go through deep lerning in this view for better accuracy.
# So i'm working on it for using deep NN.
